# %%
import bw2data as bd
import bw2io as bi
# Out:
# /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/scikits/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __import__('pkg_resources').declare_namespace(__name__)
# 16:20:17+0100 [warning  ] Can't import `SimaProBlockCSVImporter` - please install `bw2io` with `pip install bw2io[multifunctional]` or install `multifunctional` and `bw_simapro_csv` manually.

# %%
bd.projects.set_current("optimex_remind")

# %%
ecoinvent_username = "xxx" # fill in your data here
ecoinvent_password = "xxx"
premise_key = "xxx" # to be asked from premise maintainers

# %%
bi.import_ecoinvent_release(
    version="3.12",
    system_model="cutoff",
    username=ecoinvent_username,
    password=ecoinvent_password,
)
# Out:
# Applying strategy: normalize_units
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: ensure_categories_are_tuples
# Applied 3 strategies in 0.01 seconds
# Graph statistics for `ecoinvent-3.12-biosphere` importer:
# 9850 graph nodes:
# 	emission: 9477
# 	natural resource: 353
# 	inventory indicator: 15
# 	economic: 5
# 0 graph edges:
# 0 edges to the following databases:
# 0 unique unlinked edges (0 total):
# 100%|██████████| 9850/9850 [00:00<00:00, 25149.23it/s]
# 15:05:45+0100 [info     ] Vacuuming database
# Created database: ecoinvent-3.12-biosphere
# Extracting XML data from 26533 datasets
# /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/scikits/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __import__('pkg_resources').declare_namespace(__name__)
# /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/scikits/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __import__('pkg_resources').declare_namespace(__name__)
# /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/scikits/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __import__('pkg_resources').declare_namespace(__name__)
# /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/scikits/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __import__('pkg_resources').declare_namespace(__name__)
# /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/scikits/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __import__('pkg_resources').declare_namespace(__name__)
# /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/scikits/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __import__('pkg_resources').declare_namespace(__name__)
# /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/scikits/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __import__('pkg_resources').declare_namespace(__name__)
# /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/scikits/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __import__('pkg_resources').declare_namespace(__name__)
# /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/scikits/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __import__('pkg_resources').declare_namespace(__name__)
# /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/scikits/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __import__('pkg_resources').declare_namespace(__name__)
# 15:05:48+0100 [warning  ] Can't import `SimaProBlockCSVImporter` - please install `bw2io` with `pip install bw2io[multifunctional]` or install `multifunctional` and `bw_simapro_csv` manually.
# 15:05:48+0100 [warning  ] Can't import `SimaProBlockCSVImporter` - please install `bw2io` with `pip install bw2io[multifunctional]` or install `multifunctional` and `bw_simapro_csv` manually.
# 15:05:48+0100 [warning  ] Can't import `SimaProBlockCSVImporter` - please install `bw2io` with `pip install bw2io[multifunctional]` or install `multifunctional` and `bw_simapro_csv` manually.
# 15:05:48+0100 [warning  ] Can't import `SimaProBlockCSVImporter` - please install `bw2io` with `pip install bw2io[multifunctional]` or install `multifunctional` and `bw_simapro_csv` manually.
# 15:05:48+0100 [warning  ] Can't import `SimaProBlockCSVImporter` - please install `bw2io` with `pip install bw2io[multifunctional]` or install `multifunctional` and `bw_simapro_csv` manually.
# 15:05:48+0100 [warning  ] Can't import `SimaProBlockCSVImporter` - please install `bw2io` with `pip install bw2io[multifunctional]` or install `multifunctional` and `bw_simapro_csv` manually.
# 15:05:48+0100 [warning  ] Can't import `SimaProBlockCSVImporter` - please install `bw2io` with `pip install bw2io[multifunctional]` or install `multifunctional` and `bw_simapro_csv` manually.
# 15:05:48+0100 [warning  ] Can't import `SimaProBlockCSVImporter` - please install `bw2io` with `pip install bw2io[multifunctional]` or install `multifunctional` and `bw_simapro_csv` manually.
# 15:05:48+0100 [warning  ] Can't import `SimaProBlockCSVImporter` - please install `bw2io` with `pip install bw2io[multifunctional]` or install `multifunctional` and `bw_simapro_csv` manually.
# 15:05:48+0100 [warning  ] Can't import `SimaProBlockCSVImporter` - please install `bw2io` with `pip install bw2io[multifunctional]` or install `multifunctional` and `bw_simapro_csv` manually.
# 15:06:18+0100 [info     ] Extracted 26533 datasets in 33.12 seconds
# Applying strategy: normalize_units
# Applying strategy: update_ecoinvent_locations
# Applying strategy: remove_zero_amount_coproducts
# Applying strategy: remove_zero_amount_inputs_with_no_activity
# Applying strategy: remove_unnamed_parameters
# Applying strategy: es2_assign_only_product_with_amount_as_reference_product
# Applying strategy: assign_single_product_as_activity
# Applying strategy: create_composite_code
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: fix_ecoinvent_flows_pre35
# Applying strategy: drop_temporary_outdated_biosphere_flows
# Applying strategy: link_biosphere_by_flow_uuid
# Applying strategy: link_internal_technosphere_by_composite_code
# Applying strategy: delete_exchanges_missing_activity
# Applying strategy: delete_ghost_exchanges
# Applying strategy: remove_uncertainty_from_negative_loss_exchanges
# Applying strategy: fix_unreasonably_high_lognormal_uncertainties
# Applying strategy: convert_activity_parameters_to_list
# Applying strategy: add_cpc_classification_from_single_reference_product
# Applying strategy: delete_none_synonyms
# Applying strategy: update_social_flows_in_older_consequential
# Applying strategy: set_lognormal_loc_value
# Applied 22 strategies in 5.67 seconds
# Graph statistics for `ecoinvent-3.12-cutoff` importer:
# 26533 graph nodes:
# 	process: 26533
# 892943 graph edges:
# 	biosphere: 553892
# 	technosphere: 312518
# 	production: 26533
# 892943 edges to the following databases:
# 	ecoinvent-3.12-biosphere: 553892
# 	ecoinvent-3.12-cutoff: 339051
# 0 unique unlinked edges (0 total):
#
#
# 15:06:25+0100 [warning  ] Not able to determine geocollections for all datasets. This database is not ready for regionalization.
# 100%|██████████| 26533/26533 [00:44<00:00, 597.80it/s]
# 15:07:10+0100 [info     ] Vacuuming database
# Created database: ecoinvent-3.12-cutoff

# %%
import premise

# %%
ndb = premise.NewDatabase(
    scenarios=[
        {"model": "REMIND-EU", "pathway": "SSP2-NDC", "year": 2020},
        {"model": "REMIND-EU", "pathway": "SSP2-NDC", "year": 2030},
        {"model": "REMIND-EU", "pathway": "SSP2-NDC", "year": 2040},
        {"model": "REMIND-EU", "pathway": "SSP2-NDC", "year": 2050},
        {"model": "REMIND-EU", "pathway": "SSP2-NDC", "year": 2075},
        {"model": "REMIND-EU", "pathway": "SSP2-NDC", "year": 2100},
    ],
    source_db="ecoinvent-3.12-cutoff",  # <-- name of the database in the BW2 project. Must be a string.
    source_version="3.12",  # <-- version of ecoinvent. Can be "3.8", "3.9" or "3.10". Must be a string.
    key=premise_key,  # to be requested from the library maintainers if you want to use default scenarios included in `premise`
    biosphere_name="ecoinvent-3.12-biosphere",  # <-- name of the biosphere database in the BW2 project. Must be a string.
)

ndb.update()

db_names = [
    "ei312_REMIND-EU_SSP2_NDC_2020",
    "ei312_REMIND-EU_SSP2_NDC_2030",
    "ei312_REMIND-EU_SSP2_NDC_2040",
    "ei312_REMIND-EU_SSP2_NDC_2050",
    "ei312_REMIND-EU_SSP2_NDC_2075",
    "ei312_REMIND-EU_SSP2_NDC_2100",
]

ndb.write_db_to_brightway(db_names)
# Out:
# Cannot find the IAM scenario file at /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/iam_output_files/remind-eu_SSP2-NDC. Will check online.
# Cannot find the IAM scenario file at /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/iam_output_files/remind-eu_SSP2-NDC. Will check online.
# Cannot find the IAM scenario file at /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/iam_output_files/remind-eu_SSP2-NDC. Will check online.
# Cannot find the IAM scenario file at /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/iam_output_files/remind-eu_SSP2-NDC. Will check online.
# Cannot find the IAM scenario file at /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/iam_output_files/remind-eu_SSP2-NDC. Will check online.
# Cannot find the IAM scenario file at /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/iam_output_files/remind-eu_SSP2-NDC. Will check online.
# premise v.(2, 3, 4)
# +------------------------------------------------------------------+
# | Warning                                                          |
# +------------------------------------------------------------------+
# | Because some of the scenarios can yield LCI databases            |
# | containing net negative emission technologies (NET),             |
# | it is advised to account for biogenic CO2 flows when calculating |
# | Global Warming potential indicators.                             |
# | `premise_gwp` provides characterization factors for such flows.  |
# | It also provides factors for hydrogen emissions to air.          |
# |                                                                  |
# | Within your Brightway project:                                   |
# | from premise_gwp import add_premise_gwp                          |
# | add_premise_gwp()                                                |
# +------------------------------------------------------------------+
# +--------------------------------+----------------------------------+
# | Utils functions                | Description                      |
# +--------------------------------+----------------------------------+
# | clear_cache()                  | Clears the cache folder. Useful  |
# |                                | when updating `premise`or        |
# |                                | encountering issues with         |
# |                                | inventories.                     |
# | get_regions_definition(model)  | Retrieves the list of countries  |
# |                                | for each region of the model.    |
# | ndb.NewDatabase(...)           | Generates a summary of the most  |
# | ndb.generate_scenario_report() | important scenarios' variables.  |
# +--------------------------------+----------------------------------+
# Keep uncertainty data?
# NewDatabase(..., keep_source_db_uncertainty=True), keep_imports_uncertainty=True)
#
# Hide these messages?
# NewDatabase(..., quiet=True)
# - Extracting source database
# Cannot find cached database. Will create one now for next time...
# Getting activity data
# 100%|██████████| 26533/26533 [00:00<00:00, 354562.09it/s]
# Adding exchange data to activities
# 100%|██████████| 892943/892943 [01:00<00:00, 14824.18it/s]
# Filling out exchange data
# 100%|██████████| 26533/26533 [00:04<00:00, 5339.90it/s]
# Set missing location of datasets to global scope.
# Set missing location of production exchanges to scope of dataset.
# Correct missing location of technosphere exchanges.
# Correct missing flow categories for biosphere exchanges
# Remove empty exchanges.
# Remove uncertainty data.
# - Extracting inventories
# Cannot find cached inventories. Will create them now for next time...
# Importing default inventories...
#
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-Carma-CCS.xlsx
# Extracted 1 worksheets in 0.09 seconds
# Migration route: 3.5 → 3.6 → 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.5 -> 3.6
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.6 -> 3.7
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-co-firing-power-plants.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.5 → 3.6 → 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.5 -> 3.6
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.6 -> 3.7
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-combined-heat-power-plant-CCS.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.5 → 3.6 → 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.5 -> 3.6
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.6 -> 3.7
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-carbon-capture.xlsx
# Extracted 1 worksheets in 0.04 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-biogas.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.6 → 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.6 -> 3.7
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-waste-CHP.xlsx
# Extracted 4 worksheets in 0.13 seconds
# Migration route: 3.10 → 3.11 → 3.12
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-carbon-fiber.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-lithium.xlsx
# Extracted 7 worksheets in 0.31 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-cobalt.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-batteries-NMC955-LTO.xlsx
# Extracted 1 worksheets in 0.03 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+-------------------------------+
# |              Name              |       Reference product        | Location |              File             |
# +--------------------------------+--------------------------------+----------+-------------------------------+
# | market for battery management  | battery management system, for |   GLO    | lci-batteries-NMC955-LTO.xlsx |
# | battery management system prod | battery management system, for |   GLO    | lci-batteries-NMC955-LTO.xlsx |
# +--------------------------------+--------------------------------+----------+-------------------------------+
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-batteries-LiS.xlsx
# Extracted 1 worksheets in 0.17 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-batteries-LiO2.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-batteries-vanadium.xlsx
# Extracted 1 worksheets in 0.03 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+-----------------------------+
# |              Name              |       Reference product        | Location |             File            |
# +--------------------------------+--------------------------------+----------+-----------------------------+
# | market for styrene butadiene r | styrene butadiene rubber (SBR) |   RER    | lci-batteries-vanadium.xlsx |
# +--------------------------------+--------------------------------+----------+-----------------------------+
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-batteries-vanadium-redox-flow.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-batteries-organic-and-hybrid-redox-flow.xlsx
# Extracted 1 worksheets in 0.03 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Could not find a biosphere flow for ('Heat, waste', 'air', 'lower stratosphere + upper troposphere', 'megajoule') in lci-batteries-organic-and-hybrid-redox-flow.xlsx. You need to fix this.
# Could not find a biosphere flow for ('Heat, waste', 'air', 'lower stratosphere + upper troposphere', 'megajoule') in lci-batteries-organic-and-hybrid-redox-flow.xlsx. You need to fix this.
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-batteries-SIB.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-battery-capacity.xlsx
# Extracted 2 worksheets in 0.01 seconds
# Migration route: 3.10 → 3.11 → 3.12
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-home-batteries.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-heat-pump-high-temp.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.11 → 3.12
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-PV.xlsx
# Extracted 2 worksheets in 0.96 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+-------------+
# |              Name              |       Reference product        | Location |     File    |
# +--------------------------------+--------------------------------+----------+-------------+
# | 1,1-difluoroethane production  |       1,1-difluoroethane       |    US    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | electricity production, photov |    electricity, low voltage    |    CH    | lci-PV.xlsx |
# | fluorspar production, 97% puri |     fluorspar, 97% purity      |   GLO    | lci-PV.xlsx |
# | metallization paste production | metallization paste, back side |   RER    | lci-PV.xlsx |
# | metallization paste production | metallization paste, back side |   RER    | lci-PV.xlsx |
# | metallization paste production | metallization paste, front sid |   RER    | lci-PV.xlsx |
# |   multi-Si wafer production    |         multi-Si wafer         |   RER    | lci-PV.xlsx |
# | photovoltaic facade installati | photovoltaic facade installati |    CH    | lci-PV.xlsx |
# | photovoltaic facade installati | photovoltaic facade installati |    CH    | lci-PV.xlsx |
# | photovoltaic facade installati | photovoltaic facade installati |    CH    | lci-PV.xlsx |
# | photovoltaic facade installati | photovoltaic facade installati |    CH    | lci-PV.xlsx |
# | photovoltaic flat-roof install | photovoltaic flat-roof install |    CH    | lci-PV.xlsx |
# | photovoltaic flat-roof install | photovoltaic flat-roof install |    CH    | lci-PV.xlsx |
# | photovoltaic laminate producti | photovoltaic laminate, multi-S |   RER    | lci-PV.xlsx |
# | photovoltaic laminate producti | photovoltaic laminate, single- |   RER    | lci-PV.xlsx |
# | photovoltaic module production | photovoltaic module, building- |   RER    | lci-PV.xlsx |
# | photovoltaic module production | photovoltaic module, building- |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic mounting system p | photovoltaic mounting system,  |   RER    | lci-PV.xlsx |
# | photovoltaic panel factory con |   photovoltaic panel factory   |   GLO    | lci-PV.xlsx |
# | photovoltaic panel production, | photovoltaic panel, multi-Si w |   RER    | lci-PV.xlsx |
# | photovoltaic panel production, | photovoltaic panel, single-Si  |   RER    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaic slanted-roof inst | photovoltaic slanted-roof inst |    CH    | lci-PV.xlsx |
# | photovoltaics, electric instal | photovoltaics, electric instal |    CH    | lci-PV.xlsx |
# |  polyvinylfluoride production  |       polyvinylfluoride        |    US    | lci-PV.xlsx |
# | polyvinylfluoride production,  | polyvinylfluoride, dispersion  |    US    | lci-PV.xlsx |
# | polyvinylfluoride, film produc |    polyvinylfluoride, film     |    US    | lci-PV.xlsx |
# | silicon production, metallurgi |  silicon, metallurgical grade  |    NO    | lci-PV.xlsx |
# | silicon production, multi-Si,  |   silicon, multi-Si, casted    |   RER    | lci-PV.xlsx |
# | silicon production, single cry | silicon, single crystal, Czoch |   RER    | lci-PV.xlsx |
# | silicon production, solar grad |      silicon, solar grade      |   RER    | lci-PV.xlsx |
# | single-Si wafer production, ph | single-Si wafer, photovoltaic  |   RER    | lci-PV.xlsx |
# |   vinyl fluoride production    |         vinyl fluoride         |    US    | lci-PV.xlsx |
# |   wafer factory construction   |         wafer factory          |    DE    | lci-PV.xlsx |
# +--------------------------------+--------------------------------+----------+-------------+
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-PGM.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-hydrogen-electrolysis.xlsx
# Extracted 1 worksheets in 0.04 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-hydrogen-thermochemical-water-splitting.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-hydrogen-pyrolysis.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-synfuels-from-methanol-from-electrolysis.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-synfuels-from-methanol-from-cement-plant.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-hydrogen-coal-gasification.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+--------------------------------+
# |              Name              |       Reference product        | Location |              File              |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# | hydrogen production, coal gasi | hydrogen, gaseous, low pressur |   RoW    | lci-hydrogen-coal-gasification |
# | methanol production, from coal |            methanol            |    CN    | lci-hydrogen-coal-gasification |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-hydrogen-coal-gasification_CCS.xlsx
# Extracted 1 worksheets in 0.00 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-synfuels-from-methanol-from-coal.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-synfuels-from-methanol-from-coal-with-CCS.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-hydrogen-distribution.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-hydrogen-smr-atr-biogas.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-hydrogen-smr-atr-natgas.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+--------------------------------+
# |              Name              |       Reference product        | Location |              File              |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# | hydrogen production, steam met | hydrogen, gaseous, low pressur |   RER    | lci-hydrogen-smr-atr-natgas.xl |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-hydrogen-wood-gasification.xlsx
# Extracted 1 worksheets in 0.00 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-hydrogen-oil.xlsx
# Extracted 1 worksheets in 0.00 seconds
# Migration route: 3.10 → 3.11 → 3.12
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-hydrogen-turbine.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-syngas.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-synfuels-from-methanol-from-wood.xlsx
# Extracted 1 worksheets in 0.03 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+--------------------------------+
# |              Name              |       Reference product        | Location |              File              |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# | methanol production facility,  | methanol production facility,  |   RER    | lci-synfuels-from-methanol-fro |
# +--------------------------------+--------------------------------+----------+--------------------------------+
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-ammonia.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-syngas-from-coal.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-biofuels.xlsx
# Extracted 5 worksheets in 0.10 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-synfuels-from-FT-from-electrolysis.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-synfuels-from-FT-from-natural-gas.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-synfuels-from-FT-from-wood-gasification.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-synfuels-from-FT-from-wood-gasification-with-CCS.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-synfuels-from-FT-from-coal-gasification.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-synfuels-from-FT-from-coal-gasification-with-CCS.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-geothermal.xlsx
# Extracted 1 worksheets in 0.03 seconds
# Migration route: 3.6 → 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.6 -> 3.7
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-BIGCC.xlsx
# Extracted 1 worksheets in 0.00 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-nuclear_EPR.xlsx
# Extracted 1 worksheets in 0.25 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-nuclear_SMR.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# ...
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-methanol-heating.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.10 → 3.11 → 3.12
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-electric-heating.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.10 → 3.11 → 3.12
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-germanium.xlsx
# Extracted 1 worksheets in 0.03 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Could not find a biosphere flow for ('Sodium I', 'natural resource', 'in ground', 'kilogram') in lci-germanium.xlsx. You need to fix this.
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-rhenium.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-two_wheelers.xlsx
# Extracted 19 worksheets in 0.39 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-trucks.xlsx
# Extracted 1 worksheets in 0.10 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-buses.xlsx
# Extracted 1 worksheets in 0.39 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+----------------+
# |              Name              |       Reference product        | Location |      File      |
# +--------------------------------+--------------------------------+----------+----------------+
# | EV charger, level 3, plugin, 2 | EV charger, level 3, plugin, 2 |   RER    | lci-buses.xlsx |
# +--------------------------------+--------------------------------+----------+----------------+
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-pass_cars.xlsx
# Extracted 1 worksheets in 1.04 seconds
# Migration route: 3.7 → 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.7 -> 3.8
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +-----------------+-------------------+----------+--------------------+
# |       Name      | Reference product | Location |        File        |
# +-----------------+-------------------+----------+--------------------+
# | HDPE tank liner |  HDPE tank liner  |   RER    | lci-pass_cars.xlsx |
# +-----------------+-------------------+----------+--------------------+
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-rail-freight.xlsx
# Extracted 1 worksheets in 0.05 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-PV-GaAs.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.10 → 3.11 → 3.12
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-PV-perovskite.xlsx
# Extracted 1 worksheets in 0.02 seconds
# Migration route: 3.10 → 3.11 → 3.12
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-biochar-spruce.xlsx
# Extracted 1 worksheets in 0.00 seconds
# Migration route: 3.10 → 3.11 → 3.12
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-ocean-liming.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.10 → 3.11 → 3.12
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-coastal-enhanced-weathering.xlsx
# Extracted 1 worksheets in 0.00 seconds
# Migration route: 3.10 → 3.11 → 3.12
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-final-energy.xlsx
# Extracted 1 worksheets in 0.09 seconds
# Migration route: 3.10 → 3.11 → 3.12
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+--------------------------------+----------+-----------------------+
# |              Name              |       Reference product        | Location |          File         |
# +--------------------------------+--------------------------------+----------+-----------------------+
# | EV charger, level 3, plugin, 2 | EV charger, level 3, plugin, 2 |   RER    | lci-final-energy.xlsx |
# +--------------------------------+--------------------------------+----------+-----------------------+
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-sulfidic-tailings.xlsx
# Extracted 3 worksheets in 0.01 seconds
# Migration route: 3.8 → 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.8 -> 3.9
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# The following datasets to import already exist in the source database. They will not be imported
# +--------------------------------+-------------------+----------+----------------------------+
# |              Name              | Reference product | Location |            File            |
# +--------------------------------+-------------------+----------+----------------------------+
# | carbon disulfide production, f |  carbon disulfide |   GLO    | lci-sulfidic-tailings.xlsx |
# +--------------------------------+-------------------+----------+----------------------------+
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-ships.xlsx
# Extracted 1 worksheets in 0.01 seconds
# Migration route: 3.10 → 3.11 → 3.12
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Importing /Users/timodiepers/anaconda3/envs/premise/lib/python3.11/site-packages/premise/data/additional_inventories/lci-steel.xlsx
# Extracted 8 worksheets in 0.05 seconds
# Migration route: 3.9 → 3.10 → 3.11 → 3.12
# Applying forward migration 3.9 -> 3.10
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.10 -> 3.11
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Applying forward migration 3.11 -> 3.12
# Applying strategy: migrate_datasets
# Applying strategy: migrate_exchanges
# Data cached. It is advised to restart your workflow at this point.
# This allows premise to use the cached data instead, which results in
# a faster workflow.
# - Fetching IAM data
# remind-eu_SSP2-NDC.csv not found locally. Downloading...
# remind-eu_SSP2-NDC.csv: 22.4MB [00:16, 1.33MB/s]
# remind-eu_SSP2-NDC.csv downloaded successfully.
# Reading remind-eu_SSP2-NDC as CSV file
# Found file: remind-eu_SSP2-NDC
# Reading remind-eu_SSP2-NDC as CSV file
# Found file: remind-eu_SSP2-NDC
# Reading remind-eu_SSP2-NDC as CSV file
# Found file: remind-eu_SSP2-NDC
# Reading remind-eu_SSP2-NDC as CSV file
# Found file: remind-eu_SSP2-NDC
# Reading remind-eu_SSP2-NDC as CSV file
# Found file: remind-eu_SSP2-NDC
# Reading remind-eu_SSP2-NDC as CSV file
# Done!
# Processing scenarios for all sectors: 100%|█| 6/6 [13:39<00:00, 136.51
# Done!
#
# Write new database(s) to Brightway.
# Running all checks...
# Minor anomalies found: check the change report.
# 15:32:12+0100 [warning  ] Not able to determine geocollections for all datasets. This database is not ready for regionalization.
# 100%|██████████| 43648/43648 [01:44<00:00, 418.71it/s]
# 15:33:58+0100 [info     ] Vacuuming database
# Created database: ei312_REMIND-EU_SSP2_NDC_2020
# Running all checks...
# Minor anomalies found: check the change report.
# 15:36:14+0100 [warning  ] Not able to determine geocollections for all datasets. This database is not ready for regionalization.
# 100%|██████████| 43688/43688 [01:44<00:00, 418.97it/s]
# 15:38:02+0100 [info     ] Vacuuming database
# Created database: ei312_REMIND-EU_SSP2_NDC_2030
# Running all checks...
# Minor anomalies found: check the change report.
# 15:40:27+0100 [warning  ] Not able to determine geocollections for all datasets. This database is not ready for regionalization.
# 100%|██████████| 43690/43690 [01:40<00:00, 432.73it/s]
# 15:42:13+0100 [info     ] Vacuuming database
# Created database: ei312_REMIND-EU_SSP2_NDC_2040
# Running all checks...
# Minor anomalies found: check the change report.
# 15:45:14+0100 [warning  ] Not able to determine geocollections for all datasets. This database is not ready for regionalization.
# 100%|██████████| 43690/43690 [01:48<00:00, 404.52it/s]
# 15:47:08+0100 [info     ] Vacuuming database
# Created database: ei312_REMIND-EU_SSP2_NDC_2050
# Running all checks...
# Minor anomalies found: check the change report.
# 15:50:07+0100 [warning  ] Not able to determine geocollections for all datasets. This database is not ready for regionalization.
# 100%|██████████| 43690/43690 [01:38<00:00, 445.30it/s]
# 15:51:52+0100 [info     ] Vacuuming database
# Created database: ei312_REMIND-EU_SSP2_NDC_2075
# Running all checks...
# Minor anomalies found: check the change report.
# 15:55:29+0100 [warning  ] Not able to determine geocollections for all datasets. This database is not ready for regionalization.
# 100%|██████████| 43690/43690 [01:32<00:00, 473.21it/s]
# 15:57:10+0100 [info     ] Vacuuming database
# Created database: ei312_REMIND-EU_SSP2_NDC_2100
# Generate scenario report.
# Report saved under /Users/timodiepers/Documents/Coding/optimex/notebooks/export/scenario_report.
# Generate change report.
# Report saved under /Users/timodiepers/Documents/Coding/optimex/notebooks/export/change reports/.

# %%
list(bd.databases)
# Out:
# ['ecoinvent-3.12-biosphere',
#  'ecoinvent-3.12-cutoff',
#  'ei312_REMIND-EU_SSP2_NDC_2020',
#  'ei312_REMIND-EU_SSP2_NDC_2030',
#  'ei312_REMIND-EU_SSP2_NDC_2040',
#  'ei312_REMIND-EU_SSP2_NDC_2050',
#  'ei312_REMIND-EU_SSP2_NDC_2075',
#  'ei312_REMIND-EU_SSP2_NDC_2100']

# %%
from premise_gwp import add_premise_gwp

# %%
add_premise_gwp()
# Out:
# `premise_gwp` requires the name of your biosphere database.
# Please enter the name of your biosphere database as it appears in your project.
# Databases dictionary with 8 object(s):
# 	ecoinvent-3.12-biosphere
# 	ecoinvent-3.12-cutoff
# 	ei312_REMIND-EU_SSP2_NDC_2020
# 	ei312_REMIND-EU_SSP2_NDC_2030
# 	ei312_REMIND-EU_SSP2_NDC_2040
# 	ei312_REMIND-EU_SSP2_NDC_2050
# 	ei312_REMIND-EU_SSP2_NDC_2075
# 	ei312_REMIND-EU_SSP2_NDC_2100
# Using biosphere database: ecoinvent-3.12-biosphere (version (0, 8, 12))
# Adding ('IPCC 2021', 'climate change', 'GWP 20a, incl. H and bio CO2')
# Converting to ei 3.10 biosphere names
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: set_biosphere_type
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: link_iterable_by_fields
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applied 8 strategies in 0.14 seconds
# Applying strategy: drop_unlinked_cfs
# Applied 1 strategies in 0.00 seconds
# Wrote 1 LCIA methods with 196 characterization factors
# Adding ('IPCC 2021', 'climate change', 'GWP 100a, incl. H')
# Converting to ei 3.10 biosphere names
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: set_biosphere_type
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: link_iterable_by_fields
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applied 8 strategies in 0.14 seconds
# Applying strategy: drop_unlinked_cfs
# Applied 1 strategies in 0.00 seconds
# Wrote 1 LCIA methods with 190 characterization factors
# Adding ('IPCC 2021', 'climate change', 'GWP 20a, incl. H')
# Converting to ei 3.10 biosphere names
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: set_biosphere_type
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: link_iterable_by_fields
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applied 8 strategies in 0.15 seconds
# Applying strategy: drop_unlinked_cfs
# Applied 1 strategies in 0.00 seconds
# Wrote 1 LCIA methods with 190 characterization factors
# Adding ('IPCC 2021', 'climate change', 'GWP 100a, incl. H and bio CO2')
# Converting to ei 3.10 biosphere names
# Applying strategy: csv_restore_tuples
# Applying strategy: csv_numerize
# Applying strategy: csv_drop_unknown
# Applying strategy: set_biosphere_type
# Applying strategy: drop_unspecified_subcategories
# Applying strategy: link_iterable_by_fields
# Applying strategy: drop_falsey_uncertainty_fields_but_keep_zeros
# Applying strategy: convert_uncertainty_types_to_integers
# Applied 8 strategies in 0.15 seconds
# Applying strategy: drop_unlinked_cfs
# Applied 1 strategies in 0.00 seconds
# Wrote 1 LCIA methods with 196 characterization factors

# %%
add_premise_gwp??
# Out:
# Signature: add_premise_gwp()
# Docstring: <no docstring>
# Source:
# def add_premise_gwp():
#     biosphere_name = check_biosphere_database()
#     biosphere_version = check_biosphere_version(biosphere_name)
#     print(f"Using biosphere database: {biosphere_name} (version {biosphere_version})")
#
#     # impact methods to create
#     categories_bw2io087 = {
#         (
#             ("IPCC 2013", "climate change", "GWP 20a, incl. H"),
#             "kg CO2-Eq",
#             "IPCC 2013, with CFs for hydrogen",
#             "lcia_gwp_20a.xlsx",
#         ),
#         (
#             ("IPCC 2013", "climate change", "GWP 100a, incl. H"),
#             "kg CO2-Eq",
#             "IPCC 2013, with CFs for hydrogen",
#             "lcia_gwp_100a.xlsx",
#         ),
#         (
#             ("IPCC 2013", "climate change", "GWP 20a, incl. H and bio CO2"),
#             "kg CO2-Eq",
#             "IPCC 2013, with CFs for hydrogen and biogenic CO2 flows",
#             "lcia_gwp_20a_w_bio.xlsx",
#         ),
#         (
#             ("IPCC 2013", "climate change", "GWP 100a, incl. H and bio CO2"),
#             "kg CO2-Eq",
#             "IPCC 2013, with CFs for hydrogen and biogenic CO2 flows",
#             "lcia_gwp_100a_w_bio.xlsx",
#         ),
#     }
#
#     categories_bw2io088 = {
#         (
#             ("IPCC 2021", "climate change", "GWP 20a, incl. H"),
#             "kg CO2-Eq",
#             "IPCC 2021, with CFs for hydrogen",
#             "lcia_gwp2021_20a.xlsx",
#         ),
#         (
#             ("IPCC 2021", "climate change", "GWP 100a, incl. H"),
#             "kg CO2-Eq",
#             "IPCC 2021, with CFs for hydrogen",
#             "lcia_gwp2021_100a.xlsx",
#         ),
#         (
#             ("IPCC 2021", "climate change", "GWP 20a, incl. H and bio CO2"),
#             "kg CO2-Eq",
#             "IPCC 2021, with CFs for hydrogen and biogenic CO2 flows",
#             "lcia_gwp2021_20a_w_bio.xlsx",
#         ),
#         (
#             ("IPCC 2021", "climate change", "GWP 100a, incl. H and bio CO2"),
#             "kg CO2-Eq",
#             "IPCC 2021, with CFs for hydrogen and biogenic CO2 flows",
#             "lcia_gwp2021_100a_w_bio.xlsx",
#         ),
#     }
#
#     categories = (
#         categories_bw2io088 if biosphere_version >= (0, 8, 8) else categories_bw2io087
#     )
#
#     for c in categories:
#         print("Adding {}".format(c[0]))
#         category = ExcelLCIAImporter(
#             filepath=DATA_DIR / c[-1], name=c[0], unit=c[1], description=c[2]
#         )
#
#         # if bw2io < 0.8.6
#         if biosphere_version < (0, 8, 6):
#             if len(list(category.unlinked)) == 1:
#                 if list(category.unlinked)[0]["name"] == "Carbon dioxide, in air":
#                     category.drop_unlinked()
#
#         if biosphere_version == (0, 8, 12):
#             print("Converting to ei 3.10 biosphere names")
#             mapping = load_ei310_mapping()
#             for method in category.data:
#                 for flow in method["exchanges"]:
#                     flow["name"] = mapping.get(flow["name"], flow["name"])
#
#         # apply formatting strategies
#         category.apply_strategies()
#         category.drop_unlinked()
#
#         # write method
#         category.name = c[0]
#         category.write_methods(
#             overwrite=True,
#             verbose=True,
#         )
#         method = [m for m in bw2data.methods if m == c[0]][0]
#         m = bw2data.Method(method)
#         m.metadata["name"] = c[0]
# File:      ~/anaconda3/envs/premise/lib/python3.11/site-packages/premise_gwp/__init__.py
# Type:      function

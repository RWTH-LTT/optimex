# %% [markdown]
# # Mini Hydrogen Case Study

# %%
import bw2data as bd
from datetime import datetime

# %%
bd.projects.set_current("optimex_test")

# %%
if "foreground" in bd.databases:
    del bd.databases["foreground"] # to make sure we create the foreground from scratch
foreground = bd.Database("foreground")
foreground.register()

# %%
bg_meoh_biomass_gasification = bd.get_node(database="ei311_REMIND_SSP2_PkBudg650_2020", name="methanol production, biomass gasification", location="EUR")

bg_meoh_wood_ccs = bd.get_node(database="ei311_REMIND_SSP2_PkBudg650_2020", name="methanol synthesis, from wood, with CCS", location="RER")

bg_meoh_ng = bd.get_node(database="ei311_REMIND_SSP2_PkBudg650_2020", name="methanol production, from natural gas reforming", location="RER")

bg_meoh_h2_cement = bd.get_node(database="ei311_REMIND_SSP2_PkBudg650_2020", name="methanol synthesis and distillation, hydrogen from electrolysis, CO2 from cement plant", location="RER")

bg_h2_smr = bd.get_node(database="ei311_REMIND_SSP2_PkBudg650_2020", name="hydrogen production, steam methane reforming", location="EUR")

bg_h2_pem = bd.get_node(database="ei311_REMIND_SSP2_PkBudg650_2020", name="hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity", location="EUR")

# %% [markdown]
# Products:

# %%
methanol = foreground.new_node(
    name="methanol",
    unit="kg",
    type=bd.labels.product_node_default,
)
methanol.save()

hydrogen = foreground.new_node(
    name="hydrogen",
    unit="kg",
    type=bd.labels.product_node_default,
)
hydrogen.save()

captured_co2 = foreground.new_node(
    name="captured CO2",
    unit="kg",
    type=bd.labels.product_node_default,
)
captured_co2.save()

# %% [markdown]
# Processes:

# %%
def productify(background_node, new_product_node, foreground_db_name="foreground", process_name=None, process_location="GLO"):
    """
    Copies a background process to the foreground database as a new process producing a new, 
    explicit product. Keeps all non-production exchanges the unchanged. Essentially turning a 
    "processwithreferenceproduct" into a "process". Products need to be created as new nodes 
    beforehand.
    """
    assert (
        len(background_node.production()) == 1
    ), "Multifunctional process, not sure what to do"

    fg = bd.Database(foreground_db_name)

    new_name = process_name if process_name else background_node["name"]
    new_location = process_location if process_location else background_node["location"]
    
    new_process_node = fg.new_node(
        name=new_name,
        location=new_location,
        type=bd.labels.process_node_default,
    )
    new_process_node.save()

    new_process_node.new_edge(
        input=new_product_node,
        amount=1.0,
        type=bd.labels.production_edge_default,
    ).save()

    for exc in background_node.technosphere():
        new_process_node.new_edge(
            input=exc.input,
            amount=exc.amount,
            type=bd.labels.consumption_edge_default,
        ).save()

    for exc in background_node.biosphere():
        new_process_node.new_edge(
            input=exc.input,
            amount=exc.amount,
            type=bd.labels.biosphere_edge_default,
        ).save()

    return new_process_node

# %%
bg_dac = bd.get_node(database="ei311_REMIND_SSP2_PkBudg650_2020", name="carbon dioxide, captured, with a solvent-based direct air capture system, 1MtCO2", location="RER")
bg_cc_cement = bd.get_node(database="ei311_REMIND_SSP2_PkBudg650_2020", name="carbon dioxide, captured at cement production plant, integrated in fuel production chain", location="RER")

cc_cement = productify(bg_cc_cement, captured_co2, process_name="carbon capture at cement plant", process_location="RER")
dac = productify(bg_dac, captured_co2, process_name="direct air capture", process_location="RER")

# productify(bg_meoh_biomass_gasification, methanol, process_name="methanol from biomass gasification", process_location="EUR")
# productify(bg_meoh_wood_ccs, methanol, process_name="methanol from wood with CCS", process_location="RER")
# productify(bg_meoh_ng, methanol, process_name="methanol from natural gas", process_location="RER")
# productify(bg_meoh_h2_cement, methanol, process_name="methanol from H2 and cement CO2", process_location="RER")

# %%
h2_smr = productify(bg_h2_smr, hydrogen, process_name="hydrogen from SMR", process_location="EUR")
h2_pem = productify(bg_h2_pem, hydrogen, process_name="hydrogen from PEM electrolysis", process_location="EUR")

# %%
from bw_temporalis import easy_timedelta_distribution

# %%
h2_smr["operation_time_limits"] = (0, 15)
for exc in h2_smr.exchanges():
    exc["temporal_distribution"] = easy_timedelta_distribution(start=0, end=15, steps=16, kind="uniform", resolution="Y")
    exc["operation"] = True
    exc.save()
h2_smr.save()

# %%
h2_pem["operation_time_limits"] = (0, 5)
for exc in h2_pem.exchanges():
    exc["temporal_distribution"] = easy_timedelta_distribution(start=0, end=5, steps=6, kind="uniform", resolution="Y")
    exc["operation"] = True
    exc.save()
h2_pem.save()

# %%
bg_meoh_h2 = bd.get_node(database="ei311_REMIND_SSP2_PkBudg650_2020", name="methanol synthesis, hydrogen from electrolysis, CO2 from DAC", location="RER")

meoh_from_h2 = foreground.new_node(
    name="methanol production from hydrogen and captured CO2",
    location="RER",
    type=bd.labels.process_node_default,
)
meoh_from_h2.save()

meoh_from_h2.new_edge(
    input=methanol,
    amount=1.0,
    type=bd.labels.production_edge_default,
).save()

for exc in bg_meoh_h2.technosphere():
    if "carbon dioxide, captured" in exc.input["name"].lower():
        meoh_from_h2.new_edge(
            input=captured_co2,
            amount=exc.amount,
            type=bd.labels.consumption_edge_default,
        ).save()
        continue
    
    if "hydrogen production" in exc.input["name"].lower():
        meoh_from_h2.new_edge(
            input=hydrogen,
            amount=exc.amount,
            type=bd.labels.consumption_edge_default,
        ).save()
        continue
    
    meoh_from_h2.new_edge(
        input=exc.input,
        amount=exc.amount,
        type=bd.labels.consumption_edge_default,
    ).save()
    
for exc in bg_meoh_h2.biosphere():
    meoh_from_h2.new_edge(
        input=exc.input,
        amount=exc.amount,
        type=bd.labels.biosphere_edge_default,
    ).save()

# %%
meoh_from_h2["operation_time_limits"] = (0, 10)
for exc in meoh_from_h2.exchanges():
    exc["temporal_distribution"] = easy_timedelta_distribution(start=0, end=10, steps=11, kind="uniform", resolution="Y")
    exc["operation"] = True
    exc.save()
meoh_from_h2.save()

# %%
dbs = {
    2020: bd.Database("ei311_REMIND_SSP2_PkBudg650_2020"),
    2030: bd.Database("ei311_REMIND_SSP2_PkBudg650_2030"),
    2040: bd.Database("ei311_REMIND_SSP2_PkBudg650_2040"),
    2050: bd.Database("ei311_REMIND_SSP2_PkBudg650_2050"),
}

# Add representative_time metadata for each database
for year, db in dbs.items():
    db.metadata["representative_time"] = datetime(year, 1, 1).isoformat()

# %%
# exchanges = list(dac.technosphere()) + list(cc_cement.technosphere()) + list(meoh_from_h2.technosphere())

# for exc in exchanges:
#     node=exc.input
#     if node["database"] == bd.Database("ecoinvent-3.11-biosphere").name:
#         continue
#     if node["type"] != bd.labels.chimaera_node_default:
#         continue
#     for db in dbs.values():
#         node_in_other_db = db.get(
#             name=node["name"],
#             product=node.get("reference product", None),
#             location=node["location"],
#         )
#         if node["code"] != node_in_other_db["code"]:
#             node_in_other_db["code"] = node["code"]
#             node_in_other_db.save()

# %%
from bw_temporalis import TemporalDistribution
import numpy as np
import math

# Define temporally distributed demand from 2020 to 2030
years = range(2025, 2075)

amount_pattern = [10, 5] * math.ceil(len(years) / 2)
amount = np.array(amount_pattern[:len(years)], dtype=float)

td_demand = TemporalDistribution(
    date=np.array([datetime(year, 1, 1).isoformat() for year in years],
                  dtype="datetime64[s]"),
    amount=amount,
)

functional_demand = {methanol: td_demand}

# %%
from optimex import lca_processor

method = (
    "ecoinvent-3.11",
    "EF v3.1 no LT",
    "climate change no LT",
    "global warming potential (GWP100) no LT",
)

lca_config = lca_processor.LCAConfig(
    demand=functional_demand,
    temporal={
        "start_date": datetime(2020, 1, 1),
        "temporal_resolution": "year",
        "time_horizon": 100,
    },
    characterization_methods=[
        {
            "category_name": "climate_change",
            "brightway_method": method,
            "metric": "CRF",  # CRF
        },
    ],
)

# %%
from optimex import converter

lca_data_processor = lca_processor.LCADataProcessor(lca_config)
manager = converter.ModelInputManager()
optimization_model_inputs = manager.parse_from_lca_processor(lca_data_processor)
# Out:
# 2025-12-16 14:33:12.698 | INFO     | optimex.lca_processor:_parse_demand:385 - Identified demand in system time range of %s for products %s
# 2025-12-16 14:33:12.760 | INFO     | optimex.lca_processor:_construct_foreground_tensors:521 - Constructed foreground tensors.
# 2025-12-16 14:33:12.761 | INFO     | optimex.lca_processor:log_tensor_dimensions:516 - Technosphere (external) shape: (5 processes, 35 flows, 16 years) with 365 total entries.
# 2025-12-16 14:33:12.761 | INFO     | optimex.lca_processor:log_tensor_dimensions:516 - Internal demand shape: (1 processes, 2 flows, 11 years) with 22 total entries.
# 2025-12-16 14:33:12.761 | INFO     | optimex.lca_processor:log_tensor_dimensions:516 - Biosphere shape: (5 processes, 29 flows, 16 years) with 423 total entries.
# 2025-12-16 14:33:12.762 | INFO     | optimex.lca_processor:log_tensor_dimensions:516 - Production shape: (5 processes, 3 flows, 16 years) with 35 total entries.
# 2025-12-16 14:33:12.762 | INFO     | optimex.lca_processor:_calculate_inventory_of_db:560 - Calculating inventory for database: ei311_REMIND_SSP2_PkBudg650_2020
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/bw2calc/lca_base.py:127: SparseEfficiencyWarning: splu converted its input to CSC format
#   self.solver = factorized(self.technosphere_matrix)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.50e+12)
#   warnings.warn(msg, UmfpackWarning)
# 2025-12-16 14:33:16.103 | INFO     | optimex.lca_processor:_calculate_inventory_of_db:576 - Factorized LCI for database: ei311_REMIND_SSP2_PkBudg650_2020
#   3%|▎         | 1/35 [00:00<00:25,  1.32it/s]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.50e+12)
#   warnings.warn(msg, UmfpackWarning)
#   6%|▌         | 2/35 [00:01<00:20,  1.57it/s]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.50e+12)
#   warnings.warn(msg, UmfpackWarning)
#   9%|▊         | 3/35 [00:01<00:19,  1.68it/s]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.50e+12)
#   warnings.warn(msg, UmfpackWarning)
#  11%|█▏        | 4/35 [00:02<00:17,  1.73it/s]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.50e+12)
#   warnings.warn(msg, UmfpackWarning)
#  14%|█▍        | 5/35 [00:02<00:17,  1.76it/s]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.50e+12)
#   warnings.warn(msg, UmfpackWarning)
#  17%|█▋        | 6/35 [00:03<00:16,  1.78it/s]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.50e+12)
#   warnings.warn(msg, UmfpackWarning)
#  20%|██        | 7/35 [00:04<00:15,  1.79it/s]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.50e+12)
#   warnings.warn(msg, UmfpackWarning)
#  23%|██▎       | 8/35 [00:04<00:15,  1.77it/s]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 4.50e+12)
#   warnings.warn(msg, UmfpackWarning)
#
| INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:19.121 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:19.128 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:19.250 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:19.252 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:19.376 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:19.377 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:19.494 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:19.495 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:19.655 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:19.790 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:19.907 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:19.908 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:20.034 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:20.149 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:20.151 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:20.268 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:20.269 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:20.390 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:20.505 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:20.506 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:20.622 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:20.623 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:20.740 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:20.742 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:20.970 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:20.971 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:21.091 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:21.207 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:21.208 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:21.325 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:21.326 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:21.443 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:21.444 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:21.562 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:21.563 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:21.678 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:21.679 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:21.794 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:21.795 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:21.910 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:21.911 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:22.026 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:22.027 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:22.157 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:22.159 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:22.282 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:22.283 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:22.400 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:22.401 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:22.517 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:22.518 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:22.634 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:22.635 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:22.749 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:22.750 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:22.865 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:22.866 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:22.983 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:22.984 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:23.103 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:23.104 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:23.220 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:23.222 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:23.338 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:34:23.339 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:34:23.453 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# ...
# 2025-12-16 14:36:05.438 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:36:05.439 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:36:05.556 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:36:05.558 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:36:05.679 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:36:05.680 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:36:05.803 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:36:05.923 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:36:05.924 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:36:06.048 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:36:06.050 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:36:06.167 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:36:06.168 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:36:06.283 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:36:06.284 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:36:06.405 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:36:06.406 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:36:06.522 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:36:06.523 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:36:06.640 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:36:06.642 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:36:06.765 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:36:06.766 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:36:06.882 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:36:06.883 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:36:07.000 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:36:07.001 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:36:07.121 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:36:07.122 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:36:07.237 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:36:07.239 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:36:07.356 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:36:07.357 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:36:07.481 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:36:07.482 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:36:07.601 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:36:07.605 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:36:07.736 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:36:07.858 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:36:07.859 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:36:07.976 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:36:07.978 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:36:08.097 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:36:08.262 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:36:08.265 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:36:08.384 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:36:08.386 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-12-16 14:36:08.503 | WARNING  | dynamic_characterization.dynamic_characterization:characterize:133 - There are no flows to characterize. Please make sure your time horizon matches the timing of emissions and make sure there are characterization functions for the flows in the dynamic inventories.
# 2025-12-16 14:36:08.504 | INFO     | optimex.lca_processor:_construct_characterization_tensor:887 - Dynamic CRF characterization for climate_change completed.
# 2025-12-16 14:36:08.513 | INFO     | optimex.lca_processor:_construct_mapping_matrix:777 - Constructed mapping matrix for background databases based on linear interpolation.

# %%
manager.save("model_inputs.json") # if you want to save the model inputs to a file

# %%
from optimex import converter
manager = converter.ModelInputManager()

optimization_model_inputs = manager.load("model_inputs.json") # if you want to load the model inputs from a file
# Out:
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __import__('pkg_resources').declare_namespace(__name__)

# %%
from optimex import optimizer

model = optimizer.create_model(
    optimization_model_inputs,
    name = "demo_simple_example",
    objective_category = "climate_change",
)
# Out:
# 2025-12-16 14:42:28.616 | INFO     | optimex.optimizer:create_model:125 - Creating sets
# 2025-12-16 14:42:28.617 | INFO     | optimex.optimizer:create_model:167 - Creating parameters
# 2025-12-16 14:42:28.828 | INFO     | optimex.optimizer:create_model:339 - Creating variables

# %%
m, obj, results = optimizer.solve_model(model, solver_name="glpk", tee=False) # choose solver here, e.g. "gurobi", "cplex", "glpk", etc.
# Out:
# 2025-12-16 14:45:13.611 | INFO     | optimex.optimizer:solve_model:720 - Solver [glpk] termination: optimal
# 2025-12-16 14:47:08.434 | INFO     | optimex.optimizer:solve_model:745 - Objective (scaled): 0.00712286
# 2025-12-16 14:47:08.442 | INFO     | optimex.optimizer:solve_model:746 - Objective (real):   8.28655e-12

# %%
from optimex import postprocessing
pp = postprocessing.PostProcessor(m)

# %%
pp.plot_production_vs_capacity(show_capacity_changes=True)

# %%
pp.plot_impacts()

# %%
pp.plot_installation()
# Out:
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'Installed Capacity'}, xlabel='Time', ylabel='Installation'>)

# %%
pp.plot_operation()
# Out:
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'Operational Level'}, xlabel='Time', ylabel='Operation'>)

# %%
pp.plot_impacts()
# Out:
# (<Figure size 1000x600 with 1 Axes>,
#  array([<Axes: title={'center': 'climate_change'}, xlabel='Time', ylabel='Value'>,
#         <Axes: xlabel='Time', ylabel='Value'>], dtype=object))

# %%
pp.plot_installation()
# Out:
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'Installed Capacity'}, xlabel='Time', ylabel='Installation'>)

# %%
m.scales
# Out:
# {'foreground': 4.909090909090909,
#  'characterization': {'climate_change': 2.3348057260696622e-11}}

# %%
model.scales
# Out:
# {'foreground': 4.909090909090909,
#  'characterization': {'climate_change': 2.3348057260696622e-11}}

# %%
pp.get_operation()
# Out:
# Process  693b3d79849340fd9f8af7a47041607c  dac305c0bdeb4e6d8fcde37f622240d0
# Time
# 2015                                  0.0                               0.0
# 2016                                  0.0                               0.0
# 2017                                  0.0                               0.0
# 2018                                  0.0                               0.0
# 2019                                  0.0                               0.0
# 2020                                  0.0                             540.0
# 2021                                  0.0                             540.0
# 2022                                  0.0                             540.0
# 2023                                  0.0                             540.0
# 2024                                  0.0                             540.0
# 2025                                  0.0                             540.0
# 2026                                540.0                               0.0
# 2027                                540.0                               0.0
# 2028                                540.0                               0.0
# 2029                                540.0                               0.0
# 2030                                540.0                               0.0
# 2031                                540.0                               0.0
# 2032                                540.0                               0.0
# 2033                                540.0                               0.0
# 2034                                540.0                               0.0
# 2035                                540.0                               0.0
# 2036                                540.0                               0.0
# 2037                                540.0                               0.0
# 2038                                540.0                               0.0
# 2039                                540.0                               0.0
# 2040                                540.0                               0.0
# 2041                                540.0                               0.0
# 2042                                540.0                               0.0
# 2043                                540.0                               0.0
# 2044                                540.0                               0.0
# 2045                                540.0                               0.0
# 2046                                540.0                               0.0
# 2047                                540.0                               0.0
# 2048                                540.0                               0.0
# 2049                                540.0                               0.0
# 2050                                540.0                               0.0
# 2051                                540.0                               0.0
# 2052                                540.0                               0.0
# 2053                                540.0                               0.0
# 2054                                540.0                               0.0
# 2055                                540.0                               0.0
# 2056                                540.0                               0.0
# 2057                                540.0                               0.0
# 2058                                540.0                               0.0
# 2059                                540.0                               0.0
# 2060                                540.0                               0.0
# 2061                                540.0                               0.0
# 2062                                540.0                               0.0
# 2063                                540.0                               0.0
# 2064                                540.0                               0.0
# 2065                                540.0                               0.0
# 2066                                540.0                               0.0
# 2067                                540.0                               0.0
# 2068                                540.0                               0.0
# 2069                                540.0                               0.0

# %%
pp.plot_operation()
# Out:
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'Operational Level'}, xlabel='Time', ylabel='Operation'>)

# %% [markdown]
# # --------------------------

# %% [markdown]
# ### Plotting the resulting radiative forcing

# %%
import pyomo.environ as pyo 
fg_scale = getattr(pp.m, "scales", {}).get("foreground", 1.0)
inventory = {
    (p, e, t): pyo.value(pp.m.scaled_inventory[p, e, t]) * fg_scale
    for p in pp.m.PROCESS
    for e in pp.m.ELEMENTARY_FLOW
    for t in pp.m.SYSTEM_TIME
}

import pandas as pd

dynamic_inventory_df = pd.DataFrame.from_records(
    [(p, e, t, v) for (p, e, t), v in inventory.items()],
    columns=["activity", "flow", "date", "amount"]
).astype({
    "activity": "str",
    "flow": "str",
    # "date": "datetime64[s]",
    "amount": "float64"
})

dynamic_inventory_df['date'] = pd.to_datetime(dynamic_inventory_df['date'].astype(int), format='%Y')

# %%
dynamic_inventory_df
# Out:
#                                activity                                  flow  \
# 0      a5d2821e34c24d078e8efdd93b289405  e3e8f6a2-c45e-4685-9859-698b2eadaf5b
# 1      a5d2821e34c24d078e8efdd93b289405  e3e8f6a2-c45e-4685-9859-698b2eadaf5b
# 2      a5d2821e34c24d078e8efdd93b289405  e3e8f6a2-c45e-4685-9859-698b2eadaf5b
# 3      a5d2821e34c24d078e8efdd93b289405  e3e8f6a2-c45e-4685-9859-698b2eadaf5b
# 4      a5d2821e34c24d078e8efdd93b289405  e3e8f6a2-c45e-4685-9859-698b2eadaf5b
# ...                                 ...                                   ...
# 92945  34fe9823ae894b6882216398c2ce9029  dcedc211-8daa-49ac-82a9-ce60a22d9b43
# 92946  34fe9823ae894b6882216398c2ce9029  dcedc211-8daa-49ac-82a9-ce60a22d9b43
# 92947  34fe9823ae894b6882216398c2ce9029  dcedc211-8daa-49ac-82a9-ce60a22d9b43
# 92948  34fe9823ae894b6882216398c2ce9029  dcedc211-8daa-49ac-82a9-ce60a22d9b43
# 92949  34fe9823ae894b6882216398c2ce9029  dcedc211-8daa-49ac-82a9-ce60a22d9b43
#
#             date  amount
# 0     2015-01-01     0.0
# 1     2016-01-01     0.0
# 2     2017-01-01     0.0
# 3     2018-01-01     0.0
# 4     2019-01-01     0.0
# ...          ...     ...
# 92945 2065-01-01     0.0
# 92946 2066-01-01     0.0
# 92947 2067-01-01     0.0
# 92948 2068-01-01     0.0
# 92949 2069-01-01     0.0
#
# [92950 rows x 4 columns]

# %%
dynamic_inventory_df["flow"] = dynamic_inventory_df["flow"].apply(
    lambda x: bd.Database("ecoinvent-3.11-biosphere").get(code=x).id
)

# %%
from dynamic_characterization import characterize

df_characterized = characterize(
        dynamic_inventory_df,
        metric="radiative_forcing", # could also be GWP
        base_lcia_method=method,
        time_horizon=100,
        fixed_time_horizon=True,
)
# Out:
# 2025-12-10 17:27:58.254 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.

# %%
df_characterized['date'] = pd.to_datetime(df_characterized['date'])
df_grouped = (
    df_characterized
    .assign(date_rounded=(df_characterized['date'] + pd.offsets.MonthBegin(6)).dt.to_period('Y').dt.to_timestamp())
    .groupby('date_rounded')['amount'].sum()
    .reset_index()
)

df_grouped.plot(x='date_rounded', y='amount')
# Out:
# <Axes: xlabel='date_rounded'>

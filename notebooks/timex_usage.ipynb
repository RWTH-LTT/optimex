# %% [markdown]
# # Time-explicit LCA of an electric vehicle

# %% [markdown]
# This notebook shows how to use `timex_lca` with a cradle-to-grave case study of an electric vehicle. The case study is simplified, not meant to reflect the complexity of electric mobility but to demonstrate hot to use `timex_lca`.
#
# More information on the inner workings of `timex_lca` can be found [here](https://timex.readthedocs.io/en/latest/content/theory.html).

# %%
import bw2data as bd

bd.projects.set_current("optimex")
bd.databases
# Out:
# Databases dictionary with 8 object(s):
# 	biosphere3
# 	ecoinvent-3.9.1-biosphere
# 	ecoinvent-3.9.1-cutoff
# 	ei3.9.1-SSP2-RCP19-2020
# 	ei3.9.1-SSP2-RCP19-2030
# 	ei3.9.1-SSP2-RCP19-2040
# 	ei3.9.1-SSP2-RCP19-2050
# 	foreground

# %% [markdown]
# ## Prospective databases
#
# Using [Ecoinvent v3.9](https://ecoinvent.org/)  and [`premise`](https://github.com/polca/premise), we created a set of prospective databases with projections for the future electricity sectors using the SSP2-RCP19 pathway from the IAM IMAGE.

# %%
db_2020_name = "ei3.9.1-SSP2-RCP19-2020"
db_2030_name = "ei3.9.1-SSP2-RCP19-2030"
db_2040_name = "ei3.9.1-SSP2-RCP19-2040"

db_2020 = bd.Database(db_2020_name)
db_2030 = bd.Database(db_2030_name)
db_2040 = bd.Database(db_2040_name)

# %% [markdown]
# ## Case study setup

# %% [markdown]
# Let's create a new foreground database to store the EV process:

# %%
if "foreground_timex_ex" in bd.databases:
    del bd.databases["foreground_timex_ex"] # to make sure we create the foreground from scratch
foreground = bd.Database("foreground_timex_ex")
foreground.write({})

# %% [markdown]
# Getting the input processes of the EV from the background database:

# %%
db_2020.search("market for manual dismantling of used electric passenger car")
# Out:
# ['market for manual dismantling of used electric passenger car' (unit, GLO, None)]

# %%
# glider_production = bd.get_activity((db_2020_name, "133b33cc867081af144475d62179286b"))
# powertrain_production = bd.get_activity(
#     (db_2020_name, "f6d3f0b01e4a38c055e3c5c1356a4bba")
# )  # eol included
# battery_production = bd.get_activity((db_2020_name, "ba87aff6361d99be2636e8c59e55a5b2"))
# electricity_production = bd.get_activity(
#     (db_2020_name, "fec93a95a9a84d7fa0ede9c3082bb79f")
# )
# glider_eol = bd.get_activity((db_2020_name, "f8114e0ff375b3c6d72ccfa49f79e44d"))
# battery_eol = bd.get_activity((db_2020_name, "82ebcdf42e8512cbe00151dda6210d29"))

# activity_names = {
#     "glider_production": "market for glider, passenger car",
#     "powertrain_production": "market for powertrain, for electric passenger car",
#     "battery_production": "battery production, Li-ion, LiMn2O4, rechargeable, prismatic",
#     "electricity_production": "market group for electricity, low voltage",
#     "glider_eol": "market for manual dismantling of used electric passenger car",
#     "battery_eol": "market for used Li-ion battery"
# }

glider_production = [act for act in db_2020 if "market for glider, passenger car" in act["name"]][0]
powertrain_production = [act for act in db_2020 if "market for powertrain, for electric passenger car" in act["name"]][0]
battery_production = [act for act in db_2020 if "battery production, Li-ion, LiMn2O4, rechargeable, prismatic" in act["name"]][0]
electricity_production = [act for act in db_2020 if "market group for electricity, low voltage" in act["name"] and "GLO" in act["location"]][0]
glider_eol = [act for act in db_2020 if "market for manual dismantling of used electric passenger car" in act["name"]][0]
battery_eol = [act for act in db_2020 if "market for used Li-ion battery" in act["name"]][0]

# %% [markdown]
# Creating the EV activity:

# %%
fg = bd.Database("foreground_timex_ex")

# %%
fg.new_node("EV_lifecycle", name="Electric vehicle, lifecycle", unit="unit").save()
ev_lifecycle = fg.get("EV_lifecycle")

# %% [markdown]
# Here are some parameter assumptions for the EV:

# %%
ELECTRICITY_CONSUMPTION = 0.2  # kWh/km
MILEAGE = 150_000  # km
LIFETIME = 16  # years

# Overall mass: 1200 kg
MASS_GLIDER = 840  # kg
MASS_POWERTRAIN = 80  # kg
MASS_BATTERY = 280  # kg

# %% [markdown]
# Based on these parameters, we create the following exchanges:

# %%
ev_lifecycle.new_edge(input=ev_lifecycle, amount=1, type="production").save() # production exchange

# %%
glider_production_exchange = ev_lifecycle.new_edge(
    input=glider_production, 
    amount=MASS_GLIDER, 
    type="technosphere"
)

powertrain_production_exchange = ev_lifecycle.new_edge(
    input=powertrain_production, 
    amount=MASS_POWERTRAIN, 
    type="technosphere"
)

battery_production_exchange = ev_lifecycle.new_edge(
    input=battery_production, 
    amount=MASS_BATTERY, 
    type="technosphere"
)

electricity_production_exchange = ev_lifecycle.new_edge(
    input=electricity_production,
    amount=ELECTRICITY_CONSUMPTION * MILEAGE,
    type="technosphere",
)

glider_eol_exchange = ev_lifecycle.new_edge(
    input=glider_eol,
    amount=MASS_GLIDER,  # amount not negative as its not modeled as a "true" waste process
    type="technosphere",
)

battery_eol_exchange = ev_lifecycle.new_edge(
    input=battery_eol, 
    amount=-MASS_BATTERY, 
    type="technosphere"
)

# %% [markdown]
# We need to add the temporal distributions at the exchanges level.
# See [bw_temporalis documentation](https://github.com/brightway-lca/bw_temporalis) for more information on `TemporalDistribution`. Timedelta, which we use below, describes relative temporal relations, e.g. 2 years earlier.

# %%
from bw_temporalis import TemporalDistribution, easy_timedelta_distribution
import numpy as np

# %%
td_production = easy_timedelta_distribution(
    start=-4,
    end=0,
    resolution="Y",     # "Y": "Years", "M": "Months", "D": "Days", "h": "Hours" etc.
    steps=5,
    kind="triangular", # available kinds: "triangular", "uniform", "normal"
    param=-1,
)

td_use_phase = easy_timedelta_distribution(
    start=0,  # (inclusive)
    end=LIFETIME,  # (inclusive)
    resolution="Y",
    steps=(LIFETIME + 1),  # Includes both start and end
    kind="uniform",  
)

td_eol = TemporalDistribution(
    date=np.array([LIFETIME + 1], dtype="timedelta64[Y]"), amount=np.array([1])  # if you build a TD manually, make sure that length of date array == length of amount array, and the sum of elements in the amount array == 1
)

# %% [markdown]
# Let's explore what a `TemporalDistribution` looks like:

# %%
print("td_production.date [s]:  ", td_production.date)
print("td_production.amount [-]:", td_production.amount)
type(td_production)
# Out:
# td_production.date [s]:   [-126227808  -94670856  -63113904  -31556952          0]
# td_production.amount [-]: [0.         0.16666667 0.33333333 0.5        0.        ]
# bw_temporalis.temporal_distribution.TemporalDistribution

# %% [markdown]
# We now add the temporal information to the inputs of our EV. We add temporal distributions to all exchanges, but you don't have to.

# %%
glider_production_exchange["temporal_distribution"] = td_production
glider_production_exchange.save()

powertrain_production_exchange["temporal_distribution"] = td_production
powertrain_production_exchange.save()

battery_production_exchange["temporal_distribution"] = td_production
battery_production_exchange.save()

electricity_production_exchange["temporal_distribution"] = td_use_phase
electricity_production_exchange.save()

glider_eol_exchange["temporal_distribution"] = td_eol
glider_eol_exchange.save()

battery_eol_exchange["temporal_distribution"] = td_eol
battery_eol_exchange.save()

# %%
act_ev = [act for act in fg][0]
for exc in act_ev.exchanges():
    print(exc.as_dict())
# Out:
# {'output': ('foreground_timex_ex', '726c46f0629b4f7d8791c6a634011b0d'), 'input': ('foreground_timex_ex', '726c46f0629b4f7d8791c6a634011b0d'), 'amount': 1, 'type': 'production'}
# {'output': ('foreground_timex_ex', '726c46f0629b4f7d8791c6a634011b0d'), 'input': ('ei3.9.1-SSP2-RCP19-2040', 'e01f270d8d7c3b9db3939fc0cc27b05b'), 'amount': 840, 'type': 'technosphere', 'temporal_distribution': TemporalDistribution instance with 5 values and total: 1}
# {'output': ('foreground_timex_ex', '726c46f0629b4f7d8791c6a634011b0d'), 'input': ('ei3.9.1-SSP2-RCP19-2040', 'e56e73e2509e29d118cff4d782cc563a'), 'amount': 80, 'type': 'technosphere', 'temporal_distribution': TemporalDistribution instance with 5 values and total: 1}
# {'output': ('foreground_timex_ex', '726c46f0629b4f7d8791c6a634011b0d'), 'input': ('ei3.9.1-SSP2-RCP19-2040', '87a88edfedbf44a220893776c6636c8d'), 'amount': 280, 'type': 'technosphere', 'temporal_distribution': TemporalDistribution instance with 5 values and total: 1}
# {'output': ('foreground_timex_ex', '726c46f0629b4f7d8791c6a634011b0d'), 'input': ('ei3.9.1-SSP2-RCP19-2040', '29d7d9780bd00c431ea2c8193dcf35fe'), 'amount': 30000.0, 'type': 'technosphere', 'temporal_distribution': TemporalDistribution instance with 17 values and total: 1}
# {'output': ('foreground_timex_ex', '726c46f0629b4f7d8791c6a634011b0d'), 'input': ('ei3.9.1-SSP2-RCP19-2040', 'a261c7a97107e4b7da2b1b2e8ac111ac'), 'amount': 840, 'type': 'technosphere', 'temporal_distribution': TemporalDistribution instance with 1 values and total: 1}
# {'output': ('foreground_timex_ex', '726c46f0629b4f7d8791c6a634011b0d'), 'input': ('ei3.9.1-SSP2-RCP19-2040', '36d70c414913a62700d40b5ff8369568'), 'amount': -280, 'type': 'technosphere', 'temporal_distribution': TemporalDistribution instance with 1 values and total: 1}

# %% [markdown]
# ## LCA using `timex_lca`

# %% [markdown]
# As usual, we need to select a method:

# %%
method = ("EF v3.1", "climate change", "global warming potential (GWP100)")

# %% [markdown]
# `timex_lca` needs to know the representative time of the databases:

# %%
from datetime import datetime

database_date_dict = {
    db_2020_name : datetime.strptime("2020", "%Y"),
    db_2030_name : datetime.strptime("2030", "%Y"),
    db_2040_name : datetime.strptime("2040", "%Y"),
    "foreground_timex_ex": "dynamic",  # flag databases that should be temporally distributed with "dynamic"
}

# %% [markdown]
# Now, we can instantiate a `TimexLCA`. It has a similar structure as `bw2calc.LCA`, but with the additional argument `database_date_dict`.
#
# Not sure about the required inputs? Check the documentation using `?`

# %%
from bw_timex import TimexLCA
TimexLCA?
# Out:
# Init signature: TimexLCA(demand, method, database_date_dict: dict = None) -> None
# Docstring:
# Class to perform time-explicit LCA calculations.
#
# A TimexLCA retrieves the LCI of processes occuring at explicit points in time and relinks their technosphere
# exchanges to match the technology landscape at that point in time, while keeping track of the timing of the
# resulting emissions. As such, it combines prospective and dynamic LCA approaches.
#
# TimexLCA first calculates a static LCA, which informs a priority-first graph traversal. From the graph traversal,
# temporal relationships between exchanges and processes are derived. Based on the timing of the processes, bw_timex
# matches the processes at the intersection between foreground and background to the best available background
# databases. This temporal relinking is achieved by using datapackages to add new time-specific processes. The new
# processes and their exchanges to other technosphere processes or biosphere flows extent the technopshere and
# biosphere matrices.
#
# Temporal information of both processes and biosphere flows are retained, allowing for dynamic LCIA.
#
# TimexLCA calculates:
#  1) a static LCA score (`TimexLCA.static_lca.score`, same as `bw2calc.lca.score`),
#  2) a static time-explicit LCA score (`TimexLCA.score`), which links LCIs to the respective background databases but without additional temporal dynamics of the biosphere flows,
#  3) a dynamic time-explicit LCA score (`TimexLCA.dynamic_score`), with dynamic inventory and dynamic charaterization factors. These are provided for radiative forcing and GWP but can also be user-defined.
#
# Example
# -------
# >>> demand = {('my_foreground_database', 'my_process'): 1} #replace here with your functinal unit
# >>> method = ("some_method_family", "some_category", "some_method")    #replace here with your method
# >>> database_date_dict = {'my_database': datetime.strptime("2020", "%Y"),
#                           'my_foreground_database':'dynamic'} #replace here with your database dates
# >>> bw_timex = TimexLCA(demand, method, database_date_dict)
# >>> bw_timex.build_timeline() # you can pass many optional arguments here, also for the graph traversal
# >>> bw_timex.lci()
# >>> bw_timex.static_lcia()
# >>> bw_timex.static_score
# >>> bw_timex.dynamic_lcia(metric="radiative_forcing") # different metrics can be used, e.g. "GWP", "radiative_forcing"
# >>> bw_timex.dynamic_score
# Init docstring:
# Instantiating a `TimexLCA` object calculates a static LCA, initializes time mapping dicts for activities and biosphere flows, and stores useful subsets of ids in the node_id_collection_dict.
#
# Parameters
# ----------
# demand : dict[object: float]
#         The demand for which the LCA will be calculated. The keys can be Brightway `Node`
#         instances, `(database, code)` tuples, or integer ids.
# method : tuple
#         Tuple defining the LCIA method, such as `('foo', 'bar')` or default methods, such as `("EF v3.1", "climate change", "global warming potential (GWP100)")`
# database_date_dict : dict, optional
#         Dictionary mapping database names to dates.
# File:           c:\users\laytonsurface\onedrive\desktop\ltt_repos\time-explicit-life-cycle-optimization\venv\lib\site-packages\bw_timex\timex_lca.py
# Type:           type
# Subclasses:

# %% [markdown]
# Let's create a `TimexLCA` object for our EV life cycle:

# %%
tlca = TimexLCA({ev_lifecycle.key: 1}, method, database_date_dict)

# %% [markdown]
# Next, we build a timeline of the exchanges. To do this, we can call the `build_timeline()` method, which does the graph traversal and creates a timeline dataframe from the results. The exchanges (rows of the dataframe) are aggregated to the resolution specified in the argument `temporal_grouping`. There are also many more options to specify the timeline creation and graph traversal process. Here are the most important ones:
# - `temporal_grouping`: temporal resolution to which processes will be aggregated,"year" (default), "month", "day" or "hour"
# - `interpolation_type`: How the best fitting background database is selected: "linear"(default), "closest"
# - `edge_filter_function`: Custom filter function specifying when to stop the graph traversal.
# - `cutoff`: stops graph traversal for nodes below this contribution to the static impact score.
# - `max_calc`: stops graph traversal if this number of nodes has been traversed
#
# For all these options, we provide sensible default values. Of course you can always just check the docstrings to see all your options and our assumptions for default values.
#
# So, let's build the timeline:

# %%
tlca.build_timeline()
# Out:
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\timex_lca.py:182: UserWarning: No edge filter function provided. Skipping all edges within background databases.
#   warnings.warn(
# Starting graph traversal
# Calculation count: 6
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\timeline_builder.py:482: Warning: Reference date 2041-01-01 00:00:00 is higher than all provided dates. Data will be taken from the closest lower year.
#   warnings.warn(
#    date_producer                                      producer_name  \
# 0     2021-01-01  battery production, Li-ion, LiMn2O4, rechargea...
# 1     2021-01-01                   market for glider, passenger car
# 2     2021-01-01  market for powertrain, for electric passenger car
# 3     2022-01-01  battery production, Li-ion, LiMn2O4, rechargea...
# 4     2022-01-01                   market for glider, passenger car
# 5     2022-01-01  market for powertrain, for electric passenger car
# 6     2023-01-01  battery production, Li-ion, LiMn2O4, rechargea...
# 7     2023-01-01                   market for glider, passenger car
# 8     2023-01-01  market for powertrain, for electric passenger car
# 9     2024-01-01          market group for electricity, low voltage
# 10    2024-01-01                        Electric vehicle, lifecycle
# 11    2025-01-01          market group for electricity, low voltage
# 12    2026-01-01          market group for electricity, low voltage
# 13    2027-01-01          market group for electricity, low voltage
# 14    2028-01-01          market group for electricity, low voltage
# 15    2029-01-01          market group for electricity, low voltage
# 16    2030-01-01          market group for electricity, low voltage
# 17    2031-01-01          market group for electricity, low voltage
# 18    2032-01-01          market group for electricity, low voltage
# 19    2033-01-01          market group for electricity, low voltage
# 20    2034-01-01          market group for electricity, low voltage
# 21    2035-01-01          market group for electricity, low voltage
# 22    2036-01-01          market group for electricity, low voltage
# 23    2037-01-01          market group for electricity, low voltage
# 24    2038-01-01          market group for electricity, low voltage
# 25    2039-01-01          market group for electricity, low voltage
# 26    2040-01-01          market group for electricity, low voltage
# 27    2041-01-01                     market for used Li-ion battery
# 28    2041-01-01  market for manual dismantling of used electric...
#
#    date_consumer                consumer_name       amount  \
# 0     2024-01-01  Electric vehicle, lifecycle    46.666667
# 1     2024-01-01  Electric vehicle, lifecycle        140.0
# 2     2024-01-01  Electric vehicle, lifecycle    13.333333
# 3     2024-01-01  Electric vehicle, lifecycle    93.333333
# 4     2024-01-01  Electric vehicle, lifecycle        280.0
# 5     2024-01-01  Electric vehicle, lifecycle    26.666667
# 6     2024-01-01  Electric vehicle, lifecycle        140.0
# 7     2024-01-01  Electric vehicle, lifecycle        420.0
# 8     2024-01-01  Electric vehicle, lifecycle         40.0
# 9     2024-01-01  Electric vehicle, lifecycle  1764.705882
# 10    2024-01-01                           -1          1.0
# 11    2024-01-01  Electric vehicle, lifecycle  1764.705882
# 12    2024-01-01  Electric vehicle, lifecycle  1764.705882
# 13    2024-01-01  Electric vehicle, lifecycle  1764.705882
# 14    2024-01-01  Electric vehicle, lifecycle  1764.705882
# 15    2024-01-01  Electric vehicle, lifecycle  1764.705882
# 16    2024-01-01  Electric vehicle, lifecycle  1764.705882
# 17    2024-01-01  Electric vehicle, lifecycle  1764.705882
# 18    2024-01-01  Electric vehicle, lifecycle  1764.705882
# 19    2024-01-01  Electric vehicle, lifecycle  1764.705882
# 20    2024-01-01  Electric vehicle, lifecycle  1764.705882
# 21    2024-01-01  Electric vehicle, lifecycle  1764.705882
# 22    2024-01-01  Electric vehicle, lifecycle  1764.705882
# 23    2024-01-01  Electric vehicle, lifecycle  1764.705882
# 24    2024-01-01  Electric vehicle, lifecycle  1764.705882
# 25    2024-01-01  Electric vehicle, lifecycle  1764.705882
# 26    2024-01-01  Electric vehicle, lifecycle  1764.705882
# 27    2024-01-01  Electric vehicle, lifecycle       -280.0
# 28    2024-01-01  Electric vehicle, lifecycle        840.0
#
#                                 interpolation_weights
# 0   {'ei3.9.1-SSP2-RCP19-2020': 0.8998083766767041...
# 1   {'ei3.9.1-SSP2-RCP19-2020': 0.8998083766767041...
# 2   {'ei3.9.1-SSP2-RCP19-2020': 0.8998083766767041...
# 3   {'ei3.9.1-SSP2-RCP19-2020': 0.7998905009581166...
# 4   {'ei3.9.1-SSP2-RCP19-2020': 0.7998905009581166...
# 5   {'ei3.9.1-SSP2-RCP19-2020': 0.7998905009581166...
# 6   {'ei3.9.1-SSP2-RCP19-2020': 0.6999726252395291...
# 7   {'ei3.9.1-SSP2-RCP19-2020': 0.6999726252395291...
# 8   {'ei3.9.1-SSP2-RCP19-2020': 0.6999726252395291...
# 9   {'ei3.9.1-SSP2-RCP19-2020': 0.6000547495209416...
# 10                                               None
# 11  {'ei3.9.1-SSP2-RCP19-2020': 0.4998631261976457...
# 12  {'ei3.9.1-SSP2-RCP19-2020': 0.3999452504790582...
# 13  {'ei3.9.1-SSP2-RCP19-2020': 0.3000273747604708...
# 14  {'ei3.9.1-SSP2-RCP19-2020': 0.2001094990418833...
# 15  {'ei3.9.1-SSP2-RCP19-2020': 0.0999178757185874...
# 16                     {'ei3.9.1-SSP2-RCP19-2030': 1}
# 17  {'ei3.9.1-SSP2-RCP19-2030': 0.9000547645125958...
# 18  {'ei3.9.1-SSP2-RCP19-2030': 0.8001095290251916...
# 19  {'ei3.9.1-SSP2-RCP19-2030': 0.6998904709748084...
# 20  {'ei3.9.1-SSP2-RCP19-2030': 0.5999452354874042...
# 21  {'ei3.9.1-SSP2-RCP19-2030': 0.5, 'ei3.9.1-SSP2...
# 22  {'ei3.9.1-SSP2-RCP19-2030': 0.4000547645125958...
# 23  {'ei3.9.1-SSP2-RCP19-2030': 0.2998357064622124...
# 24  {'ei3.9.1-SSP2-RCP19-2030': 0.1998904709748082...
# 25  {'ei3.9.1-SSP2-RCP19-2030': 0.0999452354874042...
# 26                     {'ei3.9.1-SSP2-RCP19-2040': 1}
# 27                     {'ei3.9.1-SSP2-RCP19-2040': 1}
# 28                     {'ei3.9.1-SSP2-RCP19-2040': 1}

# %% [markdown]
# The interpolation weights in the timeline (right most column above) specify the share of the amount of an exchange to be sourced from the respective database.
# `None` means that the exchange is in the foreground supply chain, and not at the intersection with the background system.

# %% [markdown]
# Next, we calculate the time-explicit LCI. The `TimexLCA.lci()` function takes care of all the relinking, based on the information from the timeline.

# %%
tlca.lci()

# %% [markdown]
# Taking a look at the `dynamic_inventory` that was now created, we can see that it has more rows (emissions) than our usual biosphere3 flows. Instead of one row for each emission in the biosphere database we now get one row for each emission at each point in time.

# %%
tlca.dynamic_inventory
# Out:
# <65499x75126 sparse matrix of type '<class 'numpy.float64'>'
# 	with 75189 stored elements in Compressed Sparse Row format>

# %% [markdown]
# The standard, non-dynamic inventory has far less rows because the temporal resolution is missing. Looking at the timeline again, we see that we have processes at 21 different points in time, which should exactly match the ratio of the dimensions of our two inventories:

# %%
tlca.inventory
# Out:
# <3119x75126 sparse matrix of type '<class 'numpy.float64'>'
# 	with 968358 stored elements in Compressed Sparse Row format>

# %%
tlca.dynamic_inventory.shape[0] / tlca.inventory.shape[0]
# Out:
# 21.0

# %% [markdown]
# If we are only interested in the new overall time-explicit scores and don't care about the timing of the emissions, we can set `build_dynamic_biosphere=False` (default is `True`), which saves time and memory. In that case, you only get the `TimexLCA.inventory`, but not the `TimexLCA.dynamic_inventory`.

# %% [markdown]
# In case the timing of emissions is not important, one can directly calculate the LCIA the "standard way" using static characterization methods. Per default, the following calculates the static lcia score based on the impact method chosen in the very beginning:

# %%
tlca.static_lcia()
tlca.score   #kg CO2-eq
# Out:
# 16023.426151864802

# %% [markdown]
# ## Dynamic Characterization
# In addition to the standard static characterization, the time-explicit, dynamic inventory generated by a `TimexLCA` allows for dynamic characterization. Users can provide their own dynamic characterization functions and link them to corresponding biosphere flows (see example on [dynamic characterization](https://github.com/TimoDiepers/timex/blob/main/notebooks/example_simple_dynamic_characterization.ipynb)), or use the ones we provide out of the box.
#
# We provide two different metrics for dynamic LCIA of Climate Change: Radiative forcing [W/m2] and Global Warming Potential (GWP) [kg CO2-eq]. For both of these metrics, we have parameterized dynamic characterization functions for all GHG's that [IPCC AR6](https://www.ipcc.ch/report/ar6/wg1/chapter/chapter-7/) provides data for.
#
# For the dynamic characterization, users can also choose the length of the considered time horizon (`time_horizon`) and whether it is a fixed time horizon (`fixed_time_horizon`). Fixed means that the time horizon for all emissions (no matter when they occur) starts counting at the time of the functional unit, resulting in shorter time horizons for emissions occuring later. If the time horizon is not fixed (this is what conventional impact assessment factors assume), it starts counting from the timing of the emission.

# %% [markdown]
# ### Radiative forcing

# %% [markdown]
# Let's characterize our dynamic inventory, regarding radiative forcing with a fixed time horizon and the default time horizon length of 100 years:

# %%
tlca.dynamic_lcia(metric="radiative_forcing", fixed_time_horizon=True)
# Out:
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\dynamic_characterization.py:71: UserWarning: No custom dynamic characterization functions provided. Using default dynamic characterization functions based on IPCC AR6 meant to work with biosphere3 flows. The flows that are characterized are based on the selection of the initially chosen impact category: ('EF v3.1', 'climate change', 'global warming potential (GWP100)'). You can look up the mapping in the bw_timex.dynamic_characterizer.characterization_function_dict.
#   warnings.warn(
#                       date        amount  flow  \
# 0      2022-01-01 05:49:12  2.280893e-30  1991
# 152    2022-01-01 05:49:12  7.176794e-20    96
# 153    2022-01-01 05:49:12  2.028879e-18  4250
# 154    2022-01-01 05:49:12  2.382994e-29  1619
# 155    2022-01-01 05:49:12  6.008756e-20  1168
# ...                    ...           ...   ...
# 145298 2123-01-01 21:14:24  7.848107e-18  1367
# 145297 2123-01-01 21:14:24 -8.111128e-20  3626
# 145296 2123-01-01 21:14:24  2.904182e-37  1619
# 145294 2123-01-01 21:14:24  7.227404e-17  1644
# 145369 2123-01-01 21:14:24 -2.122754e-27  4249
#
#                                                 flow_name  activity  \
# 0                                     Sulfur hexafluoride     49675
# 152                                                Butane     41980
# 153     Ethane, 1,1,2-trichloro-1,2,2-trifluoro-, CFC-113     41980
# 154                     Methane, chlorodifluoro-, HCFC-22     49675
# 155                                Carbon dioxide, fossil     49210
# ...                                                   ...       ...
# 145298                       Ethane, hexafluoro-, HFC-116     35216
# 145297           Carbon dioxide, to soil or biomass stock     35216
# 145296                  Methane, chlorodifluoro-, HCFC-22     44159
# 145294                                    Methane, fossil     35216
# 145369  Ethane, 1,2-dichloro-1,1,2,2-tetrafluoro-, CFC...     35216
#
#                                             activity_name    amount_sum
# 0       (ei3.9.1-SSP2-RCP19-2020, e56e73e2509e29d118cf...  2.280893e-30
# 152     (ei3.9.1-SSP2-RCP19-2020, 87a88edfedbf44a22089...  1.635746e-12
# 153     (ei3.9.1-SSP2-RCP19-2020, 87a88edfedbf44a22089...  1.635748e-12
# 154     (ei3.9.1-SSP2-RCP19-2020, e56e73e2509e29d118cf...  1.635748e-12
# 155     (ei3.9.1-SSP2-RCP19-2020, e01f270d8d7c3b9db393...  1.635748e-12
# ...                                                   ...           ...
# 145298  (ei3.9.1-SSP2-RCP19-2020, 36d70c414913a62700d4...  1.377802e-09
# 145297  (ei3.9.1-SSP2-RCP19-2020, 36d70c414913a62700d4...  1.377802e-09
# 145296  (ei3.9.1-SSP2-RCP19-2020, a261c7a97107e4b7da2b...  1.377802e-09
# 145294  (ei3.9.1-SSP2-RCP19-2020, 36d70c414913a62700d4...  1.377780e-09
# 145369  (ei3.9.1-SSP2-RCP19-2020, 36d70c414913a62700d4...  1.377854e-09
#
# [145370 rows x 7 columns]

# %% [markdown]
# The method call returns a dataframe of all the individual emissions at their respective timesteps, but we can also just look at the overall score:

# %%
tlca.dynamic_score #W/m2 (radiative forcing)
# Out:
# 1.3778544649449214e-09

# %% [markdown]
# To visualize the results, we provide a simple plotting functions:

# %%
tlca.plot_dynamic_characterized_inventory(sum_emissions_within_activity=True)

# %% [markdown]
# Without summing up the emissions within the activity, one can see that there are also negative emissions in the system, which stem from the premise-induced BECCS in the future electricity production:

# %%
tlca.plot_dynamic_characterized_inventory()

# %% [markdown]
# There is also a flag to plot the cumulative radiative forcing:

# %%
tlca.plot_dynamic_characterized_inventory(sum_activities= True, cumsum=True)

# %% [markdown]
# ### GWP

# %% [markdown]
# Similar options are available for the metric GWP, which compares the radiative forcing of a GHG to that of CO2 over a certain time horizon (commonly 100 years, but it can be set flexibly in `time_horizon`).

# %%
tlca.dynamic_lcia(metric="GWP", fixed_time_horizon=False, time_horizon = 70)
tlca.dynamic_score #kg CO2-eq (GWP)
# Out:
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\dynamic_characterization.py:71: UserWarning: No custom dynamic characterization functions provided. Using default dynamic characterization functions based on IPCC AR6 meant to work with biosphere3 flows. The flows that are characterized are based on the selection of the initially chosen impact category: ('EF v3.1', 'climate change', 'global warming potential (GWP100)'). You can look up the mapping in the bw_timex.dynamic_characterizer.characterization_function_dict.
#   warnings.warn(
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\dynamic_characterization.py:123: UserWarning: Using bw_timex's default CO2 characterization function for GWP reference.
#   warnings.warn(
# 16229.701774704274

# %% [markdown]
# Plotting the GWP results over time:

# %%
tlca.plot_dynamic_characterized_inventory()

# %% [markdown]
# Cumulative:

# %%
tlca.plot_dynamic_characterized_inventory(sum_emissions_within_activity=True, cumsum=True)

# %% [markdown]
# ### Comparison of time-explicit results to static results
# It's helpful to understand how the time-explicit results differ from those using static assessments.
#
# We compare the time-explicit results with those of an LCA for the year 2020 and 2040 for the standard GWP100 metric (time horizon=100 and no fixed time horizon). This means we neglect the additional differences of the time-explicit results that would arise from using dynamic LCIA.

# %% [markdown]
# Time-explicit scores:

# %%
tlca.dynamic_lcia(metric="GWP", fixed_time_horizon=False, time_horizon=100)
tlca.dynamic_score
# Out:
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\dynamic_characterization.py:71: UserWarning: No custom dynamic characterization functions provided. Using default dynamic characterization functions based on IPCC AR6 meant to work with biosphere3 flows. The flows that are characterized are based on the selection of the initially chosen impact category: ('EF v3.1', 'climate change', 'global warming potential (GWP100)'). You can look up the mapping in the bw_timex.dynamic_characterizer.characterization_function_dict.
#   warnings.warn(
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\dynamic_characterization.py:123: UserWarning: Using bw_timex's default CO2 characterization function for GWP reference.
#   warnings.warn(
# 15776.777344474573

# %% [markdown]
# The 2020 (static) score has already been calculated by TimexLCA in the beginning, originally to set the priorities for the graph traversal. But we can still access the score:

# %%
tlca.static_lca.score
# Out:
# 31343.510851727835

# %% [markdown]
# However, further down we also want to look at what part of the life cycle has what contribution. To get this info, we need some more calculations:

# %%
import bw2calc as bc

static_scores = {}
for e in ev_lifecycle.exchanges():
    if e.input == ev_lifecycle.key:
        continue
    lca = bc.LCA({e.input: e.amount}, method)
    lca.lci() # one could probably do this more efficiently by using .redo_lcia, but who doesn't like a 15s break :)
    lca.lcia()
    static_scores[e.input["name"]] = lca.score

# %% [markdown]
# Similarly, we calculate the 2040 (prospective) scores by just changing the database the exchanges point to:

# %%
#first create a copy of the system and relink to processes from 2040 database
prospective_ev_lifecycle = ev_lifecycle.copy()

for exc in prospective_ev_lifecycle.exchanges():
    if exc.input == prospective_ev_lifecycle:
        continue
    exc.input = bd.get_node(
        **{
            "database": db_2040_name,
            "name": exc.input["name"],
            "product": exc.input["reference product"],
            "location": exc.input["location"],
        }
    )
    exc.save()

prospective_scores = {}
for e in prospective_ev_lifecycle.exchanges():
    if e.input == prospective_ev_lifecycle.key:
        continue
    lca = bc.LCA({e.input: e.amount}, method)
    lca.lci()
    lca.lcia()
    prospective_scores[e.input["name"]] = lca.score

# %% [markdown]
# Lets compare the overall scores:

# %%
print("Static score: ", sum(static_scores.values())) # should be the same as tlca.static_lca.score
print("Prospective score: ", sum(prospective_scores.values()))
print("Time-explicit score: ", tlca.dynamic_score)
# Out:
# Static score:  31343.51085157611
# Prospective score:  8669.563360283215
# Time-explicit score:  15776.777344474573

# %% [markdown]
# To better understand what's going on, let's plot the scores as a waterfall chart  based on timing of emission. Also, we can look at the "first-level contributions":

# %%
from timex_lca.utils import plot_characterized_inventory_as_waterfall

order_stacked_activities = (
    [  # to sort stacked bars in waterfall plot chronologically from production to EoL
        "market for glider, passenger car",
        "market for powertrain, for electric passenger car",
        "battery production, Li-ion, LiMn2O4, rechargeable, prismatic",
        "market group for electricity, low voltage",
        "market for manual dismantling of used electric passenger car",
        "market for used Li-ion battery",
    ]
)

plot_characterized_inventory_as_waterfall(
    tlca.characterized_inventory,
    metric=tlca.metric,
    static_scores=static_scores,
    prospective_scores=prospective_scores,
    order_stacked_activities=order_stacked_activities,
)

# %% [markdown]
# One can see that the time-explicit results (in the middle) are somewhere in between the static and the prospective results. This makes sense as at each timestep, the underlying processes are sourced from progressively "cleaner" background databases, reaching a lower impact than if they are only sourced from the current database, but not so low as the prospective results, which are fully sourced from the most decarbonized database. Notably, the electricity consumption in the use-phase, modelled uniformly over the lifetime of the EV, contributes less and less to the score in the later years, since the electricity becomes cleaner in the future databases.

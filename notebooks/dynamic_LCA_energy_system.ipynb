# %%
import bw2data as bd
import bw2io as bi
from pprint import pprint

bd.projects.set_current("optimex")
bd.databases
# Out:
# Databases dictionary with 8 object(s):
# 	biosphere3
# 	ecoinvent-3.9.1-biosphere
# 	ecoinvent-3.9.1-cutoff
# 	ei3.9.1-SSP2-RCP19-2020
# 	ei3.9.1-SSP2-RCP19-2030
# 	ei3.9.1-SSP2-RCP19-2040
# 	ei3.9.1-SSP2-RCP19-2050
# 	foreground

# %%
# prospective databases
db_2020_name = "ei3.9.1-SSP2-RCP19-2020"
db_2030_name = "ei3.9.1-SSP2-RCP19-2030"
db_2040_name = "ei3.9.1-SSP2-RCP19-2040"

eidb = bd.Database("ecoinvent-3.9.1-cutoff")
db_2020 = bd.Database(db_2020_name)
db_2030 = bd.Database(db_2030_name)
db_2040 = bd.Database(db_2040_name)

# %%
# dict_electricity = {
#     "wind": bd.get_activity((eidb, "24ec283aa11d98c3832b5556ac811cd2")),
#     "lignite": bd.get_activity((eidb, "f34dea30e935bc65b1d20422c30b0592")),
#     "gas": bd.get_activity((eidb, "383cb0b4ff9abe80582141530301591a")),
#     "solar": bd.get_activity((eidb, "0105e3a970d2bf162c500e0285a4b3a9"))
# }

dict_el_org_activities = {
    "wind": [act for act in db_2020 if "electricity production, wind, >3MW turbine, onshore" in act["name"] and "DE" in act["location"]][0],
    "lignite": [act for act in db_2020 if "electricity production, lignite" in act["name"] and "DE" in act["location"]][0],
    "gas": [act for act in db_2020 if "electricity production, natural gas, combined cycle power plant" in act["name"] and "DE" in act["location"]][0],
    "solar": [act for act in db_2020 if "electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, panel, mounted" in act["name"] and "DE" in act["location"]][0]
}

# %%
for name, act in dict_el_org_activities.items():
    print(name, act)
    for i, exchange in enumerate(act.exchanges()):
        print(f'{i} (flowtype {exchange["type"]}): {exchange}')
    print("\n")
# Out:
# wind 'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, DE, None)
# 0 (flowtype production): Exchange: 1.0 kilowatt hour 'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, DE, None) to 'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, DE, None)>
# 1 (flowtype production): Exchange: -4.9149577534990385e-05 kilogram 'market for waste mineral oil' (kilogram, Europe without Switzerland, None) to 'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, DE, None)>
# 2 (flowtype technosphere): Exchange: 6.9346848263762695e-09 unit 'market for wind turbine, 4.5MW, onshore' (unit, GLO, None) to 'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, DE, None)>
# 3 (flowtype technosphere): Exchange: 6.9346848263762695e-09 unit 'market for wind turbine network connection, 4.5MW, onshore' (unit, GLO, None) to 'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, DE, None)>
# 4 (flowtype technosphere): Exchange: 4.9149577534990385e-05 kilogram 'market for lubricating oil' (kilogram, RER, None) to 'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, DE, None)>
# 5 (flowtype technosphere): Exchange: 1.36334726060644e-12 ton kilometer 'market for transport, freight, lorry 7.5-16 metric ton, EURO3' (ton kilometer, RER, None) to 'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, DE, None)>
# 6 (flowtype biosphere): Exchange: 3.869999885559082 megajoule 'Energy, kinetic (in wind), converted' (megajoule, None, ('natural resource', 'in air')) to 'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, DE, None)>
#
#
# lignite 'electricity production, lignite' (kilowatt hour, DE, None)
# 0 (flowtype production): Exchange: -5.702923590433784e-05 kilogram 'market for residue from cooling tower' (kilogram, RoW, None) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 1 (flowtype production): Exchange: -0.08132369071245193 kilogram 'market for lignite ash' (kilogram, RoW, None) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 2 (flowtype production): Exchange: 1.0 kilowatt hour 'electricity production, lignite' (kilowatt hour, DE, None) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 3 (flowtype technosphere): Exchange: 1.3116724491119385 kilogram 'market for lignite' (kilogram, RER, None) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 4 (flowtype technosphere): Exchange: 0.011314600706100464 kilogram 'market for SOx retained, in lignite flue gas desulfurisation' (kilogram, GLO, None) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 5 (flowtype technosphere): Exchange: 1.1086484161260124e-11 unit 'lignite power plant construction' (unit, RER, None) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 6 (flowtype technosphere): Exchange: 0.0023039812222123146 kilogram 'market for NOx retained, by selective catalytic reduction' (kilogram, GLO, None) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 7 (flowtype technosphere): Exchange: 0.06843508780002594 kilogram 'market for water, completely softened' (kilogram, RER, None) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 8 (flowtype technosphere): Exchange: 1.7108771800994873 kilogram 'market for water, decarbonised' (kilogram, DE, None) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 9 (flowtype technosphere): Exchange: 0.00011405847180867568 kilogram 'market for chlorine, liquid' (kilogram, RER, None) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 10 (flowtype biosphere): Exchange: 0.06409864872694016 cubic meter 'Water, cooling, unspecified natural origin' (cubic meter, None, ('natural resource', 'in water')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 11 (flowtype biosphere): Exchange: 1.4941660408940294e-10 kilogram 'Antimony ion' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 12 (flowtype biosphere): Exchange: 4.972949341208732e-08 kilogram 'Barium II' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 13 (flowtype biosphere): Exchange: 2.4750688680796884e-06 kilogram 'Benzene' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 14 (flowtype biosphere): Exchange: 2.2811693940055777e-12 kilogram 'Benzo(a)pyrene' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 15 (flowtype biosphere): Exchange: 2.361010410822928e-05 kilogram 'Boron' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 16 (flowtype biosphere): Exchange: 3.148013831832941e-07 kilogram 'Bromine' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 17 (flowtype biosphere): Exchange: 2.1671110062015941e-07 kilogram 'Butane' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 18 (flowtype biosphere): Exchange: 1.745094624361343e-10 kilogram 'Cadmium II' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 19 (flowtype biosphere): Exchange: 1.165068507194519 kilogram 'Carbon dioxide, fossil' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 20 (flowtype biosphere): Exchange: 0.00022811694361735135 kilogram 'Carbon monoxide, fossil' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 21 (flowtype biosphere): Exchange: 2.2127344401212667e-09 kilogram 'Chromium III' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 22 (flowtype biosphere): Exchange: 2.737403359542867e-10 kilogram 'Chromium VI' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 23 (flowtype biosphere): Exchange: 9.9573049805457e-10 kilogram 'Cobalt II' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 24 (flowtype biosphere): Exchange: 2.292575240758765e-09 kilogram 'Copper ion' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 25 (flowtype biosphere): Exchange: 7.984093258490282e-14 kilogram 'Dioxins, measured as 2,3,7,8-tetrachlorodibenzo-p-dioxin' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 26 (flowtype biosphere): Exchange: 4.676397509228991e-07 kilogram 'Ethane' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 27 (flowtype biosphere): Exchange: 6.615391612285748e-07 kilogram 'Formaldehyde' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 28 (flowtype biosphere): Exchange: 2.4978805868158815e-06 kilogram 'Hydrocarbons, aliphatic, alkanes, unspecified' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 29 (flowtype biosphere): Exchange: 2.4636631223984296e-06 kilogram 'Hydrocarbons, aliphatic, unsaturated' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 30 (flowtype biosphere): Exchange: 3.341913179610856e-05 kilogram 'Hydrochloric acid' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 31 (flowtype biosphere): Exchange: 9.318577212980017e-06 kilogram 'Hydrogen fluoride' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 32 (flowtype biosphere): Exchange: 2.954114393105556e-07 kilogram 'Iodine' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 33 (flowtype biosphere): Exchange: 5.976664052553815e-09 kilogram 'Lead II' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 34 (flowtype biosphere): Exchange: 1.425730897608446e-05 kilo Becquerel 'Lead-210' (kilo Becquerel, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 35 (flowtype biosphere): Exchange: 1.243237335302183e-08 kilogram 'Manganese II' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 36 (flowtype biosphere): Exchange: 2.6233449190726787e-08 kilogram 'Mercury II' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 37 (flowtype biosphere): Exchange: 1.0900000233959872e-05 kilogram 'Methane, fossil' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 38 (flowtype biosphere): Exchange: 9.9573049805457e-10 kilogram 'Molybdenum VI' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 39 (flowtype biosphere): Exchange: 4.927326102688312e-09 kilogram 'Nickel II' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 40 (flowtype biosphere): Exchange: 1.1405847821777115e-08 kilogram 'PAH, polycyclic aromatic hydrocarbons' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 41 (flowtype biosphere): Exchange: 7.220919997052988e-06 kilogram 'Particulate Matter, > 10 um' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 42 (flowtype biosphere): Exchange: 1.6766596218076302e-06 kilogram 'Pentane' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 43 (flowtype biosphere): Exchange: 2.611939089547377e-05 kilo Becquerel 'Polonium-210' (kilo Becquerel, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 44 (flowtype biosphere): Exchange: 9.261548257200047e-06 kilo Becquerel 'Potassium-40' (kilo Becquerel, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 45 (flowtype biosphere): Exchange: 3.9920465155773854e-07 kilogram 'Propane' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 46 (flowtype biosphere): Exchange: 1.8249356514843385e-07 kilogram 'Propene' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 47 (flowtype biosphere): Exchange: 3.6954945699108066e-06 kilo Becquerel 'Radium-226' (kilo Becquerel, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 48 (flowtype biosphere): Exchange: 3.6042479223397095e-06 kilo Becquerel 'Radium-228' (kilo Becquerel, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 49 (flowtype biosphere): Exchange: 0.001574006979353726 kilo Becquerel 'Radon-220' (kilo Becquerel, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 50 (flowtype biosphere): Exchange: 0.0027944326866418123 kilo Becquerel 'Radon-222' (kilo Becquerel, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 51 (flowtype biosphere): Exchange: 3.3989426384550825e-08 kilogram 'Selenium IV' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 52 (flowtype biosphere): Exchange: 5.223878218885147e-09 kilogram 'Strontium' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 53 (flowtype biosphere): Exchange: 0.0003899777657352388 kilogram 'Sulfur dioxide' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 54 (flowtype biosphere): Exchange: 1.938994046213338e-06 kilo Becquerel 'Thorium-228' (kilo Becquerel, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 55 (flowtype biosphere): Exchange: 3.045361381737166e-06 kilo Becquerel 'Thorium-232' (kilo Becquerel, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 56 (flowtype biosphere): Exchange: 1.2432374205673113e-06 kilogram 'Toluene' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 57 (flowtype biosphere): Exchange: 3.079578846154618e-06 kilo Becquerel 'Uranium-238' (kilo Becquerel, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 58 (flowtype biosphere): Exchange: 1.2432374019155645e-09 kilogram 'Vanadium V' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 59 (flowtype biosphere): Exchange: 1.0516191650822293e-05 kilogram 'Xylene' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 60 (flowtype biosphere): Exchange: 8.714067689652438e-09 kilogram 'Zinc II' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 61 (flowtype biosphere): Exchange: 0.0016625706339254975 cubic meter 'Water' (cubic meter, None, ('air',)) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 62 (flowtype biosphere): Exchange: 0.06421539187431335 cubic meter 'Water' (cubic meter, None, ('water',)) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 63 (flowtype biosphere): Exchange: 8.417515573455603e-09 kilogram 'Arsenic ion' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 64 (flowtype biosphere): Exchange: 2.9541144613176584e-05 kilogram 'Dinitrogen monoxide' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 65 (flowtype biosphere): Exchange: 0.000767782679758966 kilogram 'Nitrogen oxides' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 66 (flowtype biosphere): Exchange: 2.3793649233994074e-05 kilogram 'Particulate Matter, < 2.5 um' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
# 67 (flowtype biosphere): Exchange: 1.297071412409423e-05 kilogram 'Particulate Matter, > 2.5 um and < 10um' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, lignite' (kilowatt hour, DE, None)>
#
#
# gas 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)
# 0 (flowtype production): Exchange: -6.382978881447343e-06 kilogram 'market for residue from cooling tower' (kilogram, RoW, None) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 1 (flowtype production): Exchange: 1.0 kilowatt hour 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 2 (flowtype technosphere): Exchange: 1.388888917069897e-11 unit 'gas power plant construction, combined cycle, 400MW electrical' (unit, RER, None) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 3 (flowtype technosphere): Exchange: 0.0382978729903698 kilogram 'market for water, completely softened' (kilogram, RER, None) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 4 (flowtype technosphere): Exchange: 0.1773049682378769 cubic meter 'market for natural gas, high pressure' (cubic meter, DE, None) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 5 (flowtype technosphere): Exchange: 1.2765957117080688 kilogram 'market for water, decarbonised' (kilogram, DE, None) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 6 (flowtype biosphere): Exchange: 0.04383404180407524 cubic meter 'Water, cooling, unspecified natural origin' (cubic meter, None, ('natural resource', 'in water')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 7 (flowtype biosphere): Exchange: 5.061701925657136e-12 kilogram 'Acenaphthene' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 8 (flowtype biosphere): Exchange: 5.106382872099857e-09 kilogram 'Acetaldehyde' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 9 (flowtype biosphere): Exchange: 7.723403996351408e-07 kilogram 'Acetic acid' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 10 (flowtype biosphere): Exchange: 5.757446963627899e-09 kilogram 'Benzene' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 11 (flowtype biosphere): Exchange: 3.376595661061521e-12 kilogram 'Benzo(a)pyrene' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 12 (flowtype biosphere): Exchange: 1.5765957983582268e-11 kilogram 'Beryllium II' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 13 (flowtype biosphere): Exchange: 5.9106382650497835e-06 kilogram 'Butane' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 14 (flowtype biosphere): Exchange: 1.4425531880135622e-09 kilogram 'Cadmium II' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 15 (flowtype biosphere): Exchange: 0.3408510684967041 kilogram 'Carbon dioxide, fossil' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 16 (flowtype biosphere): Exchange: 1.4042553630133625e-05 kilogram 'Carbon monoxide, fossil' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 17 (flowtype biosphere): Exchange: 1.8319148420431475e-09 kilogram 'Chromium III' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 18 (flowtype biosphere): Exchange: 1.097872348587714e-10 kilogram 'Cobalt II' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 19 (flowtype biosphere): Exchange: 1.8510638483288793e-16 kilogram 'Dioxins, measured as 2,3,7,8-tetrachlorodibenzo-p-dioxin' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 20 (flowtype biosphere): Exchange: 8.744680599193089e-06 kilogram 'Ethane' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 21 (flowtype biosphere): Exchange: 2.0617021334601304e-07 kilogram 'Formaldehyde' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 22 (flowtype biosphere): Exchange: 5.061702267994406e-06 kilogram 'Hexane' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 23 (flowtype biosphere): Exchange: 6.574468192077632e-10 kilogram 'Lead II' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 24 (flowtype biosphere): Exchange: 4.985106216714996e-10 kilogram 'Manganese II' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 25 (flowtype biosphere): Exchange: 4.391489394350856e-10 kilogram 'Mercury II' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 26 (flowtype biosphere): Exchange: 6.197872153279604e-06 kilogram 'Methane, fossil' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 27 (flowtype biosphere): Exchange: 2.751063821193611e-09 kilogram 'Nickel II' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 28 (flowtype biosphere): Exchange: 5.106382872099857e-08 kilogram 'PAH, polycyclic aromatic hydrocarbons' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 29 (flowtype biosphere): Exchange: 7.340425327129196e-06 kilogram 'Pentane' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 30 (flowtype biosphere): Exchange: 4.500000159168849e-06 kilogram 'Propane' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 31 (flowtype biosphere): Exchange: 1.0212765744199714e-07 kilogram 'Propionic acid' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 32 (flowtype biosphere): Exchange: 3.134042678154536e-11 kilogram 'Selenium IV' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 33 (flowtype biosphere): Exchange: 3.6510639347397955e-06 kilogram 'Sulfur dioxide' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 34 (flowtype biosphere): Exchange: 9.574468329276442e-09 kilogram 'Toluene' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 35 (flowtype biosphere): Exchange: 0.0005381361697800457 cubic meter 'Water' (cubic meter, None, ('air',)) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 36 (flowtype biosphere): Exchange: 0.044610798358917236 cubic meter 'Water' (cubic meter, None, ('water',)) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 37 (flowtype biosphere): Exchange: 2.623404271595575e-10 kilogram 'Arsenic ion' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 38 (flowtype biosphere): Exchange: 6.236170065676561e-06 kilogram 'Dinitrogen monoxide' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 39 (flowtype biosphere): Exchange: 0.00016276595124509186 kilogram 'Nitrogen oxides' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
# 40 (flowtype biosphere): Exchange: 3.1340425721282372e-06 kilogram 'Particulate Matter, < 2.5 um' (kilogram, None, ('air', 'non-urban air or from high stacks')) to 'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)>
#
#
# solar 'electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, panel, mounted' (kilowatt hour, DE, None)
# 0 (flowtype production): Exchange: 1.0 kilowatt hour 'electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, panel, mounted' (kilowatt hour, DE, None) to 'electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, panel, mounted' (kilowatt hour, DE, None)>
# 1 (flowtype production): Exchange: -6.385364031302743e-06 cubic meter 'market for wastewater, average' (cubic meter, Europe without Switzerland, None) to 'electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, panel, mounted' (kilowatt hour, DE, None)>
# 2 (flowtype technosphere): Exchange: 1.4446524801314808e-05 unit 'market for photovoltaic slanted-roof installation, 3kWp, multi-Si, panel, mounted, on roof' (unit, GLO, None) to 'electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, panel, mounted' (kilowatt hour, DE, None)>
# 3 (flowtype technosphere): Exchange: 0.006385364104062319 kilogram 'market for tap water' (kilogram, Europe without Switzerland, None) to 'electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, panel, mounted' (kilowatt hour, DE, None)>
# 4 (flowtype biosphere): Exchange: 9.578045592206763e-07 cubic meter 'Water' (cubic meter, None, ('air',)) to 'electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, panel, mounted' (kilowatt hour, DE, None)>
# 5 (flowtype biosphere): Exchange: 3.8503000736236572 megajoule 'Energy, solar, converted' (megajoule, None, ('natural resource', 'in air')) to 'electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, panel, mounted' (kilowatt hour, DE, None)>

# %%
if "foreground" in bd.databases:
    del bd.databases["foreground"] # to make sure we create the foreground from scratch
foreground = bd.Database("foreground")
foreground.write({}) 
fg = bd.Database("foreground")

# %%
def create_foreground_activity(activity: bd.backends.proxies.Activity, foreground: bd.backends.base.SQLiteBackend):
    # if foreground.get(activity["code"]):
    #     return foreground.get(activity["code"])

    foreground.new_node(
        code=activity["code"],
        name=activity["name"],
        unit=activity["unit"],
        location=activity["location"],
        reference_product=activity["reference product"],
    ).save()

    new_activity = foreground.get(activity["code"])
    
    for exchange in activity.exchanges():
        if exchange["type"] == "production":
            # to avoid multifunctionality we only create a prodction exchange for the reference product which has an amount of 1
            if exchange["amount"] != 1:
                continue
            new_activity.new_edge(
                input=new_activity,
                amount=exchange["amount"],
                type="production"
            ).save()
        else:
            new_activity.new_edge(
                input=exchange.input,
                amount=exchange["amount"],
                type=exchange["type"]
            ).save()
    
    return new_activity

for name, act in dict_el_org_activities.items():
    create_foreground_activity(act, fg)
# Out:
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw2data\backends\typos.py:91: UserWarning: Possible incorrect activity key found: Given `reference_product` but `reference product` is more common
#   warnings.warn(

# %%
[act for act in fg]
# Out:
# ['electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None),
#  'electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, panel, mounted' (kilowatt hour, DE, None),
#  'electricity production, lignite' (kilowatt hour, DE, None),
#  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, DE, None)]

# %%
from bw_temporalis import TemporalDistribution, easy_timedelta_distribution
import numpy as np

LIFETIME = 20

lifecycle_td = {}

lifecycle_td["construction"] = easy_timedelta_distribution(
    start=-4,
    end=0,
    resolution="Y",     # "Y": "Years", "M": "Months", "D": "Days", "h": "Hours" etc.
    steps=5,
    kind="uniform", # available kinds: "triangular", "uniform", "normal"
    param=-1,
)

lifecycle_td["operation"] = easy_timedelta_distribution(
    start=0,  # (inclusive)
    end=LIFETIME,  # (inclusive)
    resolution="Y",
    steps=(LIFETIME + 1),  # Includes both start and end
    kind="uniform",  
)

lifecycle_td["end_of_life"]= TemporalDistribution(
    date=np.array([LIFETIME + 1], dtype="timedelta64[Y]"), amount=np.array([1])  # if you build a TD manually, make sure that length of date array == length of amount array, and the sum of elements in the amount array == 1
)

# %%
construction_keywords = ["construct", "build", "install", "erect", "assemble", "fabricate", "manufacture"]
operation_keywords = ["use", "operation", "maintenance", "yearly"]
end_of_life_keywords = ["end of life", "decommission", "disposal", "recycling"]

def map_exchange_preliminary_to_lifecycle_phase(activity: bd.backends.proxies.Activity) -> dict[str, str]:
    mapping = {}
    for exc in activity.exchanges():
        if exc["type"] =="production":
            continue
        exc_name = exc.input["name"].lower()
        exc_comment = exc.input.get("comment", "").lower()
        lifecycle_phase = "unknown"
        
        # Determine the lifecycle phase based on the exchange name
        if any(keyword in exc_name or exc_comment for keyword in construction_keywords):
            lifecycle_phase = "construction"
        elif any(keyword in exc_name or exc_comment  for keyword in operation_keywords):
            lifecycle_phase = "operation"
        elif any(keyword in exc_name or exc_comment for keyword in end_of_life_keywords):
            lifecycle_phase = "end_of_life"

        if exc_name not in mapping:
            mapping[exc_name] = lifecycle_phase
    return mapping

# %%
dict_el_fg_activities = {}
for name, act in dict_el_org_activities.items():
    dict_el_fg_activities[name] = fg.get(act["code"])

activity_to_map = dict_el_fg_activities["wind"]

pprint(activity_to_map)
pprint('exchanges: ')
pprint(map_exchange_preliminary_to_lifecycle_phase(activity_to_map))
# Out:
# 'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, DE, None)
# 'exchanges: '
# {'energy, kinetic (in wind), converted': 'unknown',
#  'market for lubricating oil': 'construction',
#  'market for transport, freight, lorry 7.5-16 metric ton, euro3': 'construction',
#  'market for wind turbine network connection, 4.5mw, onshore': 'construction',
#  'market for wind turbine, 4.5mw, onshore': 'construction'}

# %% [markdown]
# Prompt:
# For the given mapping of an acitivity, assign each exchange one of the lifephases construction, operation or end_of_life based on the context of its name instead of unknown. Dont write any code, just do it manually by general knowledge. When in doubt assume the exchange happens in the operation phase. Write it down in a new dict of the form - key: exchange name, value: lifecycle phase

# %%
mapping = {}
mapping["gas"] = {
    'acenaphthene': 'operation',
    'acetaldehyde': 'operation',
    'acetic acid': 'operation',
    'arsenic ion': 'operation',
    'benzene': 'operation',
    'benzo(a)pyrene': 'operation',
    'beryllium ii': 'operation',
    'butane': 'operation',
    'cadmium ii': 'operation',
    'carbon dioxide, fossil': 'operation',
    'carbon monoxide, fossil': 'operation',
    'chromium iii': 'operation',
    'cobalt ii': 'operation',
    'dinitrogen monoxide': 'operation',
    'dioxins, measured as 2,3,7,8-tetrachlorodibenzo-p-dioxin': 'operation',
    'ethane': 'operation',
    'formaldehyde': 'operation',
    'hexane': 'operation',
    'lead ii': 'operation',
    'manganese ii': 'operation',
    'mercury ii': 'operation',
    'methane, fossil': 'operation',
    'nickel ii': 'operation',
    'nitrogen oxides': 'operation',
    'pah, polycyclic aromatic hydrocarbons': 'operation',
    'particulate matter, < 2.5 um': 'operation',
    'pentane': 'operation',
    'propane': 'operation',
    'propionic acid': 'operation',
    'selenium iv': 'operation',
    'sulfur dioxide': 'operation',
    'toluene': 'operation',
    'water': 'operation',
    'water, cooling, unspecified natural origin': 'operation',
    'gas power plant construction, combined cycle, 400mw electrical': 'construction',
    'market for natural gas, high pressure': 'operation',
    'market for residue from cooling tower': 'operation',
    'market for water, completely softened': 'construction',
    'market for water, decarbonised': 'construction',
    'mercury ii': 'operation',
    'methane, fossil': 'operation',
    'nickel ii': 'operation',
    'nitrogen oxides': 'operation',
    'pah, polycyclic aromatic hydrocarbons': 'operation',
    'particulate matter, < 2.5 um': 'operation',
    'pentane': 'operation',
    'propane': 'operation',
    'propionic acid': 'operation',
    'selenium iv': 'operation',
    'sulfur dioxide': 'operation',
    'toluene': 'operation',
    'water': 'operation',
    'water, cooling, unspecified natural origin': 'operation'   
}
mapping["lignite"] = {
    'antimony ion': 'operation',
    'arsenic ion': 'operation',
    'barium ii': 'operation',
    'benzene': 'operation',
    'benzo(a)pyrene': 'operation',
    'boron': 'operation',
    'bromine': 'operation',
    'butane': 'operation',
    'cadmium ii': 'operation',
    'carbon dioxide, fossil': 'operation',
    'carbon monoxide, fossil': 'operation',
    'chromium iii': 'operation',
    'chromium vi': 'operation',
    'cobalt ii': 'operation',
    'copper ion': 'operation',
    'dinitrogen monoxide': 'operation',
    'dioxins, measured as 2,3,7,8-tetrachlorodibenzo-p-dioxin': 'operation',
    'ethane': 'operation',
    'formaldehyde': 'operation',
    'hydrocarbons, aliphatic, alkanes, unspecified': 'operation',
    'hydrocarbons, aliphatic, unsaturated': 'operation',
    'hydrochloric acid': 'operation',
    'hydrogen fluoride': 'operation',
    'iodine': 'operation',
    'lead ii': 'operation',
    'lead-210': 'operation',
    'lignite power plant construction': 'construction',
    'manganese ii': 'operation',
    'market for chlorine, liquid': 'operation',
    'market for lignite': 'operation',
    'market for lignite ash': 'operation',
    'market for nox retained, by selective catalytic reduction': 'operation',
    'market for residue from cooling tower': 'operation',
    'market for sox retained, in lignite flue gas desulfurisation': 'operation',
    'market for water, completely softened': 'operation',
    'market for water, decarbonised': 'operation',
    'mercury ii': 'operation',
    'methane, fossil': 'operation',
    'molybdenum vi': 'operation',
    'nickel ii': 'operation',
    'nitrogen oxides': 'operation',
    'pah, polycyclic aromatic hydrocarbons': 'operation',
    'particulate matter, < 2.5 um': 'operation',
    'particulate matter, > 10 um': 'operation',
    'particulate matter, > 2.5 um and < 10um': 'operation',
    'pentane': 'operation',
    'polonium-210': 'operation',
    'potassium-40': 'operation',
    'propane': 'operation',
    'propene': 'operation',
    'radium-226': 'operation',
    'radium-228': 'operation',
    'radon-220': 'operation',
    'radon-222': 'operation',
    'selenium iv': 'operation',
    'strontium': 'operation',
    'sulfur dioxide': 'operation',
    'thorium-228': 'operation',
    'thorium-232': 'operation',
    'toluene': 'operation',
    'uranium-238': 'operation',
    'vanadium v': 'operation',
    'water': 'operation',
    'water, cooling, unspecified natural origin': 'operation',
    'xylene': 'operation',
    'zinc ii': 'operation'
}
mapping["solar"] = {
    'energy, solar, converted': 'operation',
    'market for photovoltaic slanted-roof installation, 3kwp, multi-si, panel, mounted, on roof': 'construction',
    'market for tap water': 'operation',
    'market for wastewater, average': 'operation',
    'water': 'operation'
}
mapping["wind"] = {
    'energy, kinetic (in wind), converted': 'operation',
    'market for lubricating oil': 'operation',
    'market for transport, freight, lorry 7.5-16 metric ton, euro3': 'operation',
    'market for waste mineral oil': 'operation',
    'market for wind turbine network connection, 4.5mw, onshore': 'construction',
    'market for wind turbine, 4.5mw, onshore': 'construction'
}

# %%
def set_temporal_distribution_of_lifecycle(activity: bd.backends.proxies.Activity, mapping: dict[str, str], temporal_distribution: dict[str, TemporalDistribution]) -> bd.backends.proxies.Activity:
    for exc in activity.exchanges():
        if exc["type"] == "production":
            continue
        exc_name = exc.input["name"].lower()
        
        if exc_name in mapping:
            lifecycle_phase = mapping[exc_name]
        else:
            print(f"Could not find lifecycle phase for exchange: {exc_name}")
            continue
        exc["lifecycle_phase"] = lifecycle_phase
        exc["temporal_distribution"] = temporal_distribution[lifecycle_phase]
        exc.save()

for name, act in dict_el_fg_activities.items():
    set_temporal_distribution_of_lifecycle(act, mapping[name], lifecycle_td)

# %%
for exc in dict_el_fg_activities["solar"].exchanges():
    print(exc.as_dict())
# Out:
# {'output': ('foreground', '0105e3a970d2bf162c500e0285a4b3a9'), 'input': ('foreground', '0105e3a970d2bf162c500e0285a4b3a9'), 'amount': 1.0, 'type': 'production'}
# {'output': ('foreground', '0105e3a970d2bf162c500e0285a4b3a9'), 'input': ('ei3.9.1-SSP2-RCP19-2020', '09a9ae111d33545514b77a45cbada56d'), 'amount': 1.4446525e-05, 'type': 'technosphere', 'lifecycle_phase': 'construction', 'temporal_distribution': TemporalDistribution instance with 5 values and total: 1}
# {'output': ('foreground', '0105e3a970d2bf162c500e0285a4b3a9'), 'input': ('ei3.9.1-SSP2-RCP19-2020', '4fe1f2dae4830593ee2d608cb2d5ff2c'), 'amount': 0.006385364, 'type': 'technosphere', 'lifecycle_phase': 'operation', 'temporal_distribution': TemporalDistribution instance with 21 values and total: 1}
# {'output': ('foreground', '0105e3a970d2bf162c500e0285a4b3a9'), 'input': ('ecoinvent-3.9.1-biosphere', '075e433b-4be4-448e-9510-9a5029c1ce94'), 'amount': 9.578046e-07, 'type': 'biosphere', 'lifecycle_phase': 'operation', 'temporal_distribution': TemporalDistribution instance with 21 values and total: 1}
# {'output': ('foreground', '0105e3a970d2bf162c500e0285a4b3a9'), 'input': ('ecoinvent-3.9.1-biosphere', 'a7ff17d4-d3fe-4a70-9f2e-392b34630772'), 'amount': 3.8503, 'type': 'biosphere', 'lifecycle_phase': 'operation', 'temporal_distribution': TemporalDistribution instance with 21 values and total: 1}

# %%
method = ("EF v3.1", "climate change", "global warming potential (GWP100)")

# %%
from datetime import datetime
from bw_timex import TimexLCA

database_date_dict = {
    db_2020_name : datetime.strptime("2020", "%Y"),
    db_2030_name : datetime.strptime("2030", "%Y"),
    db_2040_name : datetime.strptime("2040", "%Y"),
    "foreground": "dynamic",  # flag databases that should be temporally distributed with "dynamic"
}

# %%
import dill as pickle
import time
from tqdm import tqdm

tlca_results = {}

start_time = time.time()

for name, act in tqdm(dict_el_fg_activities.items()):
    print("Conducting TLCA for activity: ", act)
    tlca = TimexLCA({act: 1 }, method, database_date_dict)
    tlca_results[act] = {}
    print("Building timeline...")
    df_timeline = tlca.build_timeline()
    print("Performing LCI...")
    tlca.lci()
    print("Performing static LCA...")
    tlca.static_lcia()
    tlca_results[act]["static"] = tlca.score #kg CO2-eq
    print("Performing dynamic LCIA...")
    tlca.dynamic_lcia(metric="radiative_forcing", fixed_time_horizon=True)
    tlca_results[act]["dynamic"] = tlca.dynamic_score #W/m2 (radiative forcing)

    print("Saving TLCA object...")
    try:
        with open(f'tlca_{name}.pickle', 'wb') as f:
            pickle.dump(tlca, f)
    except Exception as e:
        print(e)

end_time = time.time()
runtime = end_time - start_time
runtime
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# Conducting TLCA for activity:  'electricity production, wind, >3MW turbine, onshore' (kilowatt hour, DE, None)
# Building timeline...
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\timex_lca.py:182: UserWarning: No edge filter function provided. Skipping all edges within background databases.
#   warnings.warn(
# Starting graph traversal
# Calculation count: 3
# Performing LCI...
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\timeline_builder.py:482: Warning: Reference date 2041-01-01 00:00:00 is higher than all provided dates. Data will be taken from the closest lower year.
#   warnings.warn(
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\timeline_builder.py:482: Warning: Reference date 2042-01-01 00:00:00 is higher than all provided dates. Data will be taken from the closest lower year.
#   warnings.warn(
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\timeline_builder.py:482: Warning: Reference date 2043-01-01 00:00:00 is higher than all provided dates. Data will be taken from the closest lower year.
#   warnings.warn(
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\timeline_builder.py:482: Warning: Reference date 2044-01-01 00:00:00 is higher than all provided dates. Data will be taken from the closest lower year.
#   warnings.warn(
# Performing static LCA...
# Performing dynamic LCIA...
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\dynamic_characterization.py:71: UserWarning: No custom dynamic characterization functions provided. Using default dynamic characterization functions based on IPCC AR6 meant to work with biosphere3 flows. The flows that are characterized are based on the selection of the initially chosen impact category: ('EF v3.1', 'climate change', 'global warming potential (GWP100)'). You can look up the mapping in the bw_timex.dynamic_characterizer.characterization_function_dict.
#   warnings.warn(
# Saving TLCA object...
#  25%|██▌       | 1/4 [12:06<36:20, 726.82s/it]
# cannot pickle 'SuperLU' object
# Conducting TLCA for activity:  'electricity production, lignite' (kilowatt hour, DE, None)
# Building timeline...
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\timex_lca.py:182: UserWarning: No edge filter function provided. Skipping all edges within background databases.
#   warnings.warn(
# Starting graph traversal
# Calculation count: 7
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\timeline_builder.py:482: Warning: Reference date 2041-01-01 00:00:00 is higher than all provided dates. Data will be taken from the closest lower year.
#   warnings.warn(
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\timeline_builder.py:482: Warning: Reference date 2042-01-01 00:00:00 is higher than all provided dates. Data will be taken from the closest lower year.
#   warnings.warn(
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\timeline_builder.py:482: Warning: Reference date 2043-01-01 00:00:00 is higher than all provided dates. Data will be taken from the closest lower year.
#   warnings.warn(
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\timeline_builder.py:482: Warning: Reference date 2044-01-01 00:00:00 is higher than all provided dates. Data will be taken from the closest lower year.
#   warnings.warn(
# Performing LCI...
# Performing static LCA...
# Performing dynamic LCIA...
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\dynamic_characterization.py:71: UserWarning: No custom dynamic characterization functions provided. Using default dynamic characterization functions based on IPCC AR6 meant to work with biosphere3 flows. The flows that are characterized are based on the selection of the initially chosen impact category: ('EF v3.1', 'climate change', 'global warming potential (GWP100)'). You can look up the mapping in the bw_timex.dynamic_characterizer.characterization_function_dict.
#   warnings.warn(
# Saving TLCA object...
#  50%|█████     | 2/4 [48:35<52:53, 1586.58s/it]
# cannot pickle 'SuperLU' object
# Conducting TLCA for activity:  'electricity production, natural gas, combined cycle power plant' (kilowatt hour, DE, None)
# Building timeline...
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\timex_lca.py:182: UserWarning: No edge filter function provided. Skipping all edges within background databases.
#   warnings.warn(
# Starting graph traversal
# Calculation count: 4
# Performing LCI...
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\timeline_builder.py:482: Warning: Reference date 2041-01-01 00:00:00 is higher than all provided dates. Data will be taken from the closest lower year.
#   warnings.warn(
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\timeline_builder.py:482: Warning: Reference date 2042-01-01 00:00:00 is higher than all provided dates. Data will be taken from the closest lower year.
#   warnings.warn(
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\timeline_builder.py:482: Warning: Reference date 2043-01-01 00:00:00 is higher than all provided dates. Data will be taken from the closest lower year.
#   warnings.warn(
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\timeline_builder.py:482: Warning: Reference date 2044-01-01 00:00:00 is higher than all provided dates. Data will be taken from the closest lower year.
#   warnings.warn(
# Performing static LCA...
# Performing dynamic LCIA...
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\dynamic_characterization.py:71: UserWarning: No custom dynamic characterization functions provided. Using default dynamic characterization functions based on IPCC AR6 meant to work with biosphere3 flows. The flows that are characterized are based on the selection of the initially chosen impact category: ('EF v3.1', 'climate change', 'global warming potential (GWP100)'). You can look up the mapping in the bw_timex.dynamic_characterizer.characterization_function_dict.
#   warnings.warn(
# Saving TLCA object...
#  75%|███████▌  | 3/4 [1:00:42<19:54, 1194.36s/it]
# cannot pickle 'SuperLU' object
# Conducting TLCA for activity:  'electricity production, photovoltaic, 3kWp slanted-roof installation, multi-Si, panel, mounted' (kilowatt hour, DE, None)
# Building timeline...
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\timex_lca.py:182: UserWarning: No edge filter function provided. Skipping all edges within background databases.
#   warnings.warn(
# Starting graph traversal
# Calculation count: 2
# Performing LCI...
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\timeline_builder.py:482: Warning: Reference date 2041-01-01 00:00:00 is higher than all provided dates. Data will be taken from the closest lower year.
#   warnings.warn(
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\timeline_builder.py:482: Warning: Reference date 2042-01-01 00:00:00 is higher than all provided dates. Data will be taken from the closest lower year.
#   warnings.warn(
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\timeline_builder.py:482: Warning: Reference date 2043-01-01 00:00:00 is higher than all provided dates. Data will be taken from the closest lower year.
#   warnings.warn(
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\timeline_builder.py:482: Warning: Reference date 2044-01-01 00:00:00 is higher than all provided dates. Data will be taken from the closest lower year.
#   warnings.warn(
# Performing static LCA...
# Performing dynamic LCIA...
# c:\Users\LaytonSurface\OneDrive\Desktop\LTT_repos\time-explicit-life-cycle-optimization\venv\Lib\site-packages\bw_timex\dynamic_characterization.py:71: UserWarning: No custom dynamic characterization functions provided. Using default dynamic characterization functions based on IPCC AR6 meant to work with biosphere3 flows. The flows that are characterized are based on the selection of the initially chosen impact category: ('EF v3.1', 'climate change', 'global warming potential (GWP100)'). You can look up the mapping in the bw_timex.dynamic_characterizer.characterization_function_dict.
#   warnings.warn(
# Saving TLCA object...
# cannot pickle 'SuperLU' object
# 100%|██████████| 4/4 [1:11:19<00:00, 1069.76s/it]
# 4279.037497282028

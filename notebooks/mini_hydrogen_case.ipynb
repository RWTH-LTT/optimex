# %% [markdown]
# # Mini Hydrogen Case Study

# %%
import bw2data as bd
from datetime import datetime
# Out:
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/__init__.py:1: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   __import__('pkg_resources').declare_namespace(__name__)

# %%
list(bd.projects)
# Out:
# [Project: default,
#  Project: Westnetz Scope3,
#  Project: LCA_EPE,
#  Project: bw25_ei310_premise,
#  Project: bw_temporalis example,
#  Project: ab_grid_status_quo_only,
#  Project: timex_example_electric_vehicle,
#  Project: __test_delayed_pulse_emission__,
#  Project: bw25_premise_background_v2,
#  Project: ab_grid_status_quo,
#  Project: dvs-studie,
#  Project: test_background_temporalization,
#  Project: Temporalis example project,
#  Project: multi-level-tds,
#  Project: __multiple_dbs_with_same_timestamp_db__,
#  Project: timex_minimal_example,
#  Project: getting_started_with_timex,
#  Project: __wastes_db__,
#  Project: __wastesasdfasdf_db__,
#  Project: __wastesasdf_db__,
#  Project: test,
#  Project: 293,
#  Project: ,
#  Project: something,
#  Project: asdfasdfasdf,
#  Project: asdf,
#  Project: sometingnew,
#  Project: löakjsdfölkjasdljkf,
#  Project: nnnnn,
#  Project: testing,
#  Project: thisisanewproject,
#  Project: electric_vehicle_standalone,
#  Project: __test_database1__,
#  Project: timex_example_dynamic_characterization,
#  Project: dynamic_lcia_demo,
#  Project: my_demo,
#  Project: bw25_plca_grid_expansion,
#  Project: dynamic_lcia_demo1,
#  Project: dynamic_lcia_demo2,
#  Project: dynamic_lcia_demo23,
#  Project: dynamic_lcia_demo233,
#  Project: AROUND,
#  Project: __test_standalone_db__,
#  Project: __test_standalone_dba__,
#  Project: basic_usage_example,
#  Project: basic_usage_example2,
#  Project: basic_usage_example3,
#  Project: brightway-example,
#  Project: standalone_optimex_example,
#  Project: ei310_SSP2_Base_2040,
#  Project: bw25_ei311_premise2.3.0dev1,
#  Project: bw25_ei311_premise2.3.0dev1_new,
#  Project: bw25_ei310_premise2.3.0dev1_new,
#  Project: ___process_at_base_database_time_db,
#  Project: timex,
#  Project: 289,
#  Project: timex_getting_started,
#  Project: timex_ev_example,
#  Project: plca_grid_expansion,
#  Project: bw_timex,
#  Project: chem_demo,
#  Project: timex_teaching,
#  Project: optimex,
#  Project: Timex_teaching_ei310,
#  Project: test_web_browser,
#  Project: lca-epe-test,
#  Project: tiemx,
#  Project: standalone_optimex_example_products,
#  Project: optimex_energy_switches]

# %%
bd.projects.set_current("bw25_ei310_premise2.3.0dev1_new")

# %%
methanol = bd.get_node(database="ei311_SSP2_PkBudg650_2025", name="market for methanol", location="RER")

# %%
list(methanol.exchanges())
# Out:
# [Exchange: 1.0 kilogram 'market for methanol' (kilogram, RER, None) to 'market for methanol' (kilogram, RER, None)>,
#  Exchange: 1.0 kilogram 'methanol production, natural gas reforming' (kilogram, RER, None) to 'market for methanol' (kilogram, RER, None)>,
#  Exchange: 0.043819669634103775 ton kilometer 'market for transport, freight, train' (ton kilometer, DEU, None) to 'market for methanol' (kilogram, RER, None)>,
#  Exchange: 0.021869035437703133 ton kilometer 'market for transport, freight, inland waterways, barge' (ton kilometer, RER, None) to 'market for methanol' (kilogram, RER, None)>,
#  Exchange: 0.17129896581172943 ton kilometer 'market for transport, freight, lorry' (ton kilometer, DEU, None) to 'market for methanol' (kilogram, RER, None)>]

# %%
[act for act in bd.Database("ei311_SSP2_PkBudg650_2025") if "methanol production, biomass gasification" in act["name"]]
# Out:
# ['methanol production, biomass gasification' (kilogram, CH, None),
#  'methanol production, biomass gasification' (kilogram, JPN, None),
#  'methanol production, biomass gasification' (kilogram, ESC, None),
#  'methanol production, biomass gasification' (kilogram, ECE, None),
#  'methanol production, biomass gasification' (kilogram, REF, None),
#  'methanol production, biomass gasification' (kilogram, MEA, None),
#  'methanol production, biomass gasification' (kilogram, World, None),
#  'methanol production, biomass gasification' (kilogram, IND, None),
#  'methanol production, biomass gasification' (kilogram, ECS, None),
#  'methanol production, biomass gasification' (kilogram, OAS, None),
#  'methanol production, biomass gasification' (kilogram, USA, None),
#  'methanol production, biomass gasification' (kilogram, LAM, None),
#  'methanol production, biomass gasification' (kilogram, NES, None),
#  'methanol production, biomass gasification' (kilogram, RoW, None),
#  'methanol production, biomass gasification' (kilogram, ENC, None),
#  'methanol production, biomass gasification' (kilogram, DEU, None),
#  'methanol production, biomass gasification' (kilogram, ESW, None),
#  'methanol production, biomass gasification' (kilogram, UKI, None),
#  'methanol production, biomass gasification' (kilogram, FRA, None),
#  'methanol production, biomass gasification' (kilogram, SSA, None),
#  'methanol production, biomass gasification' (kilogram, CHA, None),
#  'methanol production, biomass gasification' (kilogram, CAZ, None),
#  'methanol production, biomass gasification' (kilogram, NEN, None),
#  'methanol production, biomass gasification' (kilogram, EWN, None)]

# %%
bd.get_node(database="ei311_SSP2_PkBudg650_2025", name="methanol production, biomass gasification", location="World")
# Out:
# 'methanol production, biomass gasification' (kilogram, World, None)

# %%
bd.get_node(database="ei311_SSP2_PkBudg650_2025", name="methanol production, natural gas reforming", location="RER")
# Out:
# 'methanol production, natural gas reforming' (kilogram, RER, None)

# %%
bd.get_node(database="ei311_SSP2_PkBudg650_2025", name="methanol synthesis, hydrogen from electrolysis, CO2 from DAC", location="RER")
# Out:
# 'methanol synthesis, hydrogen from electrolysis, CO2 from DAC' (kilogram, RER, None)

# %%
bd.get_node(database="ei311_SSP2_PkBudg650_2025", name="methanol synthesis and distillation, hydrogen from electrolysis, CO2 from cement plant", location="RER")
# Out:
# 'methanol synthesis and distillation, hydrogen from electrolysis, CO2 from cement plant' (kilogram, RER, None)

# %%
[act for act in bd.Database("ei311_SSP2_PkBudg650_2025") if "methanol synthesis" in act["name"] and "CO2" in act["name"]]
# Out:
# ['methanol synthesis and distillation, hydrogen from electrolysis, CO2 from cement plant' (kilogram, RER, None),
#  'methanol synthesis, hydrogen from electrolysis, CO2 from DAC' (kilogram, RER, None)]

# %%
[act for act in bd.Database("ei311_SSP2_PkBudg650_2025") if "CO2 from" in act["name"]]
# Out:
# ['kerosene production, from methanol, hydrogen from electrolysis, CO2 from DAC, economic allocation' (kilogram, RER, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, FRA, None),
#  'liquefied petroleum gas production, synthetic, from methanol, hydrogen from electrolysis, CO2 from DAC, economic allocation, at fuelling station' (kilogram, RER, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, OAS, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, ECE, None),
#  'gasoline production, synthetic, from methanol, hydrogen from electrolysis, CO2 from cement plant, energy allocation, at fuelling station' (kilogram, RER, None),
#  'liquefied petroleum gas production, from methanol, hydrogen from electrolysis, CO2 from cement plant, economic allocation' (kilogram, RER, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from cement plant, economic allocation' (kilogram, RER, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, SSA, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, CHA, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, USA, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, LAM, None),
#  'diesel production, synthetic, from methanol, hydrogen from electrolysis, CO2 from cement plant, energy allocation, at fuelling station' (kilogram, RER, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, RER, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, REF, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, ESC, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, UKI, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, World, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, JPN, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, CAZ, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from cement plant, economic allocation' (kilogram, RER, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, CAZ, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, EWN, None),
#  'liquefied petroleum gas production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, RER, None),
#  'diesel production, synthetic, from methanol, hydrogen from electrolysis, CO2 from DAC, economic allocation, at fuelling station' (kilogram, RER, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from DAC, economic allocation' (kilogram, RER, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, NEN, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, ECS, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, MEA, None),
#  'kerosene production, from methanol, hydrogen from electrolysis, CO2 from cement plant, energy allocation' (kilogram, RER, None),
#  'methanol synthesis and distillation, hydrogen from electrolysis, CO2 from cement plant' (kilogram, RER, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, MEA, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, ENC, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, RER, None),
#  'kerosene production, synthetic, from methanol, hydrogen from electrolysis, CO2 from DAC, economic allocation, at fuelling station' (kilogram, RER, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, USA, None),
#  'liquefied petroleum gas production, from methanol, hydrogen from electrolysis, CO2 from DAC, economic allocation' (kilogram, RER, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, IND, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, NES, None),
#  'kerosene production, synthetic, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation, at fuelling station' (kilogram, RER, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, SSA, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, NEN, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, ENC, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, CHA, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, ECE, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, DEU, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, DEU, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from cement plant, energy allocation' (kilogram, RER, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, LAM, None),
#  'liquefied petroleum gas production, synthetic, from methanol, hydrogen from electrolysis, CO2 from cement plant, energy allocation, at fuelling station' (kilogram, RER, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, ECS, None),
#  'gasoline production, synthetic, from methanol, hydrogen from electrolysis, CO2 from cement plant, economic allocation, at fuelling station' (kilogram, RER, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, World, None),
#  'methanol distillation, hydrogen from electrolysis, CO2 from DAC' (kilogram, RER, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, NES, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, ESC, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, REF, None),
#  'methanol synthesis, hydrogen from electrolysis, CO2 from DAC' (kilogram, RER, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, FRA, None),
#  'kerosene production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, RER, None),
#  'kerosene production, from methanol, hydrogen from electrolysis, CO2 from cement plant, economic allocation' (kilogram, RER, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, IND, None),
#  'kerosene production, synthetic, from methanol, hydrogen from electrolysis, CO2 from cement plant, energy allocation, at fuelling station' (kilogram, RER, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, UKI, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, ESW, None),
#  'liquefied petroleum gas production, synthetic, from methanol, hydrogen from electrolysis, CO2 from cement plant, economic allocation, at fuelling station' (kilogram, RER, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, ESW, None),
#  'gasoline production, synthetic, from methanol, hydrogen from electrolysis, CO2 from DAC, economic allocation, at fuelling station' (kilogram, RER, None),
#  'diesel production, synthetic, from methanol, hydrogen from electrolysis, CO2 from cement plant, economic allocation, at fuelling station' (kilogram, RER, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, OAS, None),
#  'gasoline production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, JPN, None),
#  'diesel production, synthetic, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation, at fuelling station' (kilogram, RER, None),
#  'kerosene production, synthetic, from methanol, hydrogen from electrolysis, CO2 from cement plant, economic allocation, at fuelling station' (kilogram, RER, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from DAC, economic allocation' (kilogram, RER, None),
#  'gasoline production, synthetic, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation, at fuelling station' (kilogram, RER, None),
#  'liquefied petroleum gas production, from methanol, hydrogen from electrolysis, CO2 from cement plant, energy allocation' (kilogram, RER, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from cement plant, energy allocation' (kilogram, RER, None),
#  'liquefied petroleum gas production, synthetic, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation, at fuelling station' (kilogram, RER, None),
#  'diesel production, from methanol, hydrogen from electrolysis, CO2 from DAC, energy allocation' (kilogram, EWN, None)]

# %%
[act for act in bd.Database("ei311_SSP2_PkBudg650_2025") if "methanol" in act["reference product"]]
# Out:
# ['methanol production, coal gasification' (kilogram, RoW, None),
#  'methanol synthesis, from wood, with CCS' (kilogram, RER, None),
#  'market for methanol' (kilogram, CN, None),
#  'methanol production, biomass gasification' (kilogram, ENC, None),
#  'methanol production, coal gasification' (kilogram, CN, None),
#  'methanol production, biomass gasification' (kilogram, ECE, None),
#  'methanol production, biomass gasification' (kilogram, ECS, None),
#  'methanol production, biomass gasification' (kilogram, OAS, None),
#  'methanol production, biomass gasification' (kilogram, NEN, None),
#  'methanol production, biomass gasification' (kilogram, ESC, None),
#  'methanol production, biomass gasification' (kilogram, CAZ, None),
#  'methanol production, biomass gasification' (kilogram, IND, None),
#  'methanol production, biomass gasification' (kilogram, USA, None),
#  'methanol production, biomass gasification' (kilogram, SSA, None),
#  'sulfate pulp production, from hardwood, bleached' (kilogram, RER, None),
#  'methanol production facility, construction' (unit, RER, None),
#  'methanol supply, produced with biomass' (kilogram, RER, None),
#  'methanol production, biomass gasification' (kilogram, REF, None),
#  'methanol distillation, hydrogen from coal gasification' (kilogram, RER, None),
#  'methanol synthesis, hydrogen from coal gasification, with CCS' (kilogram, RER, None),
#  'methanol production, natural gas reforming' (kilogram, RoW, None),
#  'methanol supply, produced with coal' (kilogram, RER, None),
#  'methanol production, biomass gasification' (kilogram, RoW, None),
#  'methanol production, natural gas reforming' (kilogram, CN, None),
#  'methanol synthesis and distillation, hydrogen from electrolysis, CO2 from cement plant' (kilogram, RER, None),
#  'sulfate pulp production, from softwood, bleached' (kilogram, RoW, None),
#  'market for methanol, from biomass' (kilogram, RoW, None),
#  'sulfate pulp production, from hardwood, bleached' (kilogram, RoW, None),
#  'market for methanol, from biomass' (kilogram, CH, None),
#  'methanol production, natural gas reforming' (kilogram, US, None),
#  'methanol synthesis, hydrogen from coal gasification' (kilogram, RoW, None),
#  'market for methanol factory' (unit, GLO, None),
#  'methanol production, biomass gasification' (kilogram, World, None),
#  'methanol production, biomass gasification' (kilogram, UKI, None),
#  'methanol distillation, hydrogen from coal gasification, with CCS' (kilogram, RER, None),
#  'methanol distillation, hydrogen from electrolysis, CO2 from DAC' (kilogram, RER, None),
#  'methanol distillation, from wood, with CCS' (kilogram, RER, None),
#  'market for methanol' (kilogram, RoW, None),
#  'synthetic fuel production, from coal, high temperature Fisher-Tropsch operations' (kilogram, ZA, None),
#  'methanol production, biomass gasification' (kilogram, MEA, None),
#  'methanol production, biomass gasification' (kilogram, LAM, None),
#  'methanol synthesis, hydrogen from coal gasification' (kilogram, RER, None),
#  'market for methanol' (kilogram, RER, None),
#  'methanol synthesis, hydrogen from electrolysis, CO2 from DAC' (kilogram, RER, None),
#  'methanol production, biomass gasification' (kilogram, CHA, None),
#  'methanol production, biomass gasification' (kilogram, DEU, None),
#  'methanol production, biomass gasification' (kilogram, FRA, None),
#  'methanol production, natural gas reforming' (kilogram, RER, None),
#  'methanol production, biomass gasification' (kilogram, ESW, None),
#  'methanol factory construction' (unit, GLO, None),
#  'methanol production, biomass gasification' (kilogram, CH, None),
#  'methanol production, biomass gasification' (kilogram, JPN, None),
#  'sulfate pulp production, from softwood, bleached' (kilogram, RER, None),
#  'market for methanol' (kilogram, US, None),
#  'methanol supply, produced with hydrogen from Electrolysis, PEM using electricity from grid, and carbon from DAC' (kilogram, RER, None),
#  'methanol production, biomass gasification' (kilogram, NES, None),
#  'methanol production, biomass gasification' (kilogram, EWN, None)]

# %%
list(bd.databases)  # Make sure the databases are loaded
# Out:
# ['ecoinvent-3.10.1-biosphere',
#  'ecoinvent-3.10.1-cutoff',
#  'ei311_SSP2_PkBudg1000_2023',
#  'ei311_SSP2_PkBudg1000_2025',
#  'ei311_SSP2_PkBudg1000_2030',
#  'ei311_SSP2_PkBudg1000_2035',
#  'ei311_SSP2_PkBudg1000_2037',
#  'ei311_SSP2_PkBudg1000_2040',
#  'ei311_SSP2_PkBudg1000_2045',
#  'ei311_SSP2_PkBudg650_2023',
#  'ei311_SSP2_PkBudg650_2025',
#  'ei311_SSP2_PkBudg650_2030',
#  'ei311_SSP2_PkBudg650_2035',
#  'ei311_SSP2_PkBudg650_2037',
#  'ei311_SSP2_PkBudg650_2040',
#  'ei311_SSP2_PkBudg650_2045',
#  'ei311_SSP2_NPi_2023',
#  'ei311_SSP2_NPi_2025',
#  'ei311_SSP2_NPi_2030',
#  'ei311_SSP2_NPi_2035',
#  'ei311_SSP2_NPi_2037',
#  'ei311_SSP2_NPi_2040',
#  'ei311_SSP2_NPi_2045',
#  'grid_status_quo',
#  'grid_expansion_prospective',
#  'grid_components_NPi_2023',
#  'grid_components_NPi_2025',
#  'grid_components_NPi_2030',
#  'grid_components_NPi_2035',
#  'grid_components_NPi_2037',
#  'grid_components_NPi_2040',
#  'grid_components_PkBudg1000_2023',
#  'grid_components_PkBudg1000_2025',
#  'grid_components_PkBudg1000_2030',
#  'grid_components_PkBudg1000_2035',
#  'grid_components_PkBudg1000_2037',
#  'grid_components_PkBudg1000_2040',
#  'grid_components_PkBudg650_2023',
#  'grid_components_PkBudg650_2025',
#  'grid_components_PkBudg650_2030',
#  'grid_components_PkBudg650_2035',
#  'grid_components_PkBudg650_2037',
#  'grid_components_PkBudg650_2040',
#  'grid_expansion_static',
#  'new_mixes']

# %% [markdown]
# ## Data Preparation

# %%
db_bio = bd.Database("ecoinvent-3.10.1-biosphere") 

# Create a dict of databases keyed by year
dbs = {
    2025: bd.Database("ei311_SSP2_PkBudg650_2025"),
    2035: bd.Database("ei311_SSP2_PkBudg650_2035"),
    2045: bd.Database("ei311_SSP2_PkBudg650_2045"),
}

# Add representative_time metadata for each database
for year, db in dbs.items():
    db.metadata["representative_time"] = datetime(year, 1, 1).isoformat()

eidb = bd.Database("ecoinvent-3.10.1-cutoff")
db_2020 =dbs[2025]

if "foreground" in bd.databases:
    del bd.databases["foreground"] # to make sure we create the foreground from scratch
foreground = bd.Database("foreground")
foreground.write({})
foreground.register()

# %%
from collections import namedtuple
import numpy as np
import bw_temporalis as bwt

# === Define reusable structure for flow data ===
Flow = namedtuple("Flow", ["dataset", "amount", "type", "phase"])

# === Phase durations ===
timing_config = {
    "PEM_Electrolysis": {
        "construction": 2,
        "lifetime": 10,
        "decommissioning": 1,
    },
    "SMR": {
        "construction": 3,
        "lifetime": 15,
        "decommissioning": 2,
    }
}

# === Temporal distribution generators ===
def make_temporal_distributions(name):
    config = timing_config[name]
    c, l, d = config["construction"], config["lifetime"], config["decommissioning"]

    return {
        "pre_operation": lambda: bwt.easy_timedelta_distribution(
            start=0, end=c, resolution="Y", steps=c + 1,
            kind="triangular" if name == "SMR" else "uniform"
        ),
        "operation": lambda: bwt.easy_timedelta_distribution(
            start=c, end=c + l, resolution="Y", steps=l + 1, kind="uniform"
        ),
        "post_operation": lambda: bwt.TemporalDistribution(
            date=np.array([c + l + d], dtype="timedelta64[Y]"),
            amount=np.array([1])
        )
    }

temporal_distributions = {
    name: make_temporal_distributions(name)
    for name in timing_config
}

# %%
# === Important flows for PEM and SMR ===
important_flows_pem = {
    "h2_pem": Flow(db_2020.get(name="hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity", unit="kilogram", location="GLO"), 1.0, "production", "operation"),
    "electrolyzer_stack": Flow(db_2020.get(name="electrolyzer production, 1MWe, PEM, Stack"), 1.35e-6, "technosphere", "pre_operation"),
    "electrolyzer_bop": Flow(db_2020.get(name="electrolyzer production, 1MWe, PEM, Balance of Plant"), 3.37e-7, "technosphere", "pre_operation"),
    "electrolyzer_disposal_stack": Flow(db_2020.get(name="treatment of fuel cell stack, 1MWe, PEM"), -1.35e-6, "technosphere", "post_operation"),
    "electrolyzer_disposal_bop": Flow(db_2020.get(name="treatment of fuel cell balance of plant, 1MWe, PEM"), -3.37e-7, "technosphere", "post_operation"),
    "electricity": Flow(db_2020.get(name="market group for electricity, low voltage", location="WEU"), 54.0, "technosphere", "operation"),
    "water_deionised_europe": Flow(db_2020.get(name="market for water, deionised", location="Europe without Switzerland"), 14.0, "technosphere", "operation"),
    "oxygen_air": Flow(db_bio.get(name="Oxygen", categories=("air",)), 8.0, "biosphere", "operation"),
}

important_flows_smr = {
    "h2_smr": Flow(db_2020.get(name="hydrogen production, steam methane reforming", location="RER", unit="kilogram"), 1.0, "production", "operation"),
    "natural_gas_ch": Flow(db_2020.get(name="market for natural gas, high pressure", location="CH"), 0.0294, "technosphere", "operation"),
    "natural_gas_europe": Flow(db_2020.get(name="market group for natural gas, high pressure", location="Europe without Switzerland"), 4.22, "technosphere", "operation"),
    "chemical_factory_construction": Flow(db_2020.get(name="chemical factory construction, organics", location="RER"), 4.99e-10, "technosphere", "pre_operation"),
    "water_deionised_ch": Flow(db_2020.get(name="market for water, deionised", location="CH"), 0.0148, "technosphere", "operation"),
    "water_deionised_europe": Flow(db_2020.get(name="market for water, deionised", location="Europe without Switzerland"), 4.12, "technosphere", "operation"),
    "oxygen_air": Flow(db_bio.get(name="Oxygen", categories=("natural resource", "in air")), 6.07, "biosphere", "operation"),
    "cooling_water": Flow(db_bio.get(name="Water, cooling, unspecified natural origin", categories=("natural resource", "in water")), 0.355, "biosphere", "operation"),
    "co2_fossil": Flow(db_bio.get(name="Carbon dioxide, fossil", categories=("air",)), 8.35, "biosphere", "operation"),
}
# Out:
# ---------------------------------------------------------------------------
# MultipleResults                           Traceback (most recent call last)
# Cell In[9], line 3
#       1 # === Important flows for PEM and SMR ===
#       2 important_flows_pem = {
# ----> 3     "h2_pem": Flow(db_2020.get(name="hydrogen production, gaseous, 30 bar, from PEM electrolysis, from grid electricity", unit="kilogram"), 1.0, "production", "operation"),
#       4     "electrolyzer_stack": Flow(db_2020.get(name="electrolyzer production, 1MWe, PEM, Stack"), 1.35e-6, "technosphere", "pre_operation"),
#       5     "electrolyzer_bop": Flow(db_2020.get(name="electrolyzer production, 1MWe, PEM, Balance of Plant"), 3.37e-7, "technosphere", "pre_operation"),
#       6     "electrolyzer_disposal_stack": Flow(db_2020.get(name="treatment of fuel cell stack, 1MWe, PEM"), -1.35e-6, "technosphere", "post_operation"),
#       7     "electrolyzer_disposal_bop": Flow(db_2020.get(name="treatment of fuel cell balance of plant, 1MWe, PEM"), -3.37e-7, "technosphere", "post_operation"),
#       8     "electricity": Flow(db_2020.get(name="market group for electricity, low voltage", location="WEU"), 54.0, "technosphere", "operation"),
#       9     "water_deionised_europe": Flow(db_2020.get(name="market for water, deionised", location="Europe without Switzerland"), 14.0, "technosphere", "operation"),
#      10     "oxygen_air": Flow(db_bio.get(name="Oxygen", categories=("air",)), 8.0, "biosphere", "operation"),
#      11 }
#      13 important_flows_smr = {
#      14     "h2_smr": Flow(db_2020.get(name="hydrogen production, steam methane reforming", location="RER", unit="kilogram"), 1.0, "production", "operation"),
#      15     "natural_gas_ch": Flow(db_2020.get(name="market for natural gas, high pressure", location="CH"), 0.0294, "technosphere", "operation"),
#    (...)     22     "co2_fossil": Flow(db_bio.get(name="Carbon dioxide, fossil", categories=("air",)), 8.35, "biosphere", "operation"),
#      23 }
#
# File ~/anaconda3/envs/optimex/lib/python3.11/site-packages/bw2data/backends/base.py:485, in SQLiteBackend.get(self, code, **kwargs)
#     483 if code is not None:
#     484     kwargs["code"] = code
# --> 485 return get_node(**kwargs)
#
# File ~/anaconda3/envs/optimex/lib/python3.11/site-packages/bw2data/utils.py:382, in get_node(**kwargs)
#     376     candidates = [
#     377         obj
#     378         for obj in candidates
#     379         if all(obj.get(key) == value for key, value in kwargs.items() if key not in mapping)
#     380     ]
#     381 if len(candidates) > 1:
# --> 382     raise MultipleResults("Found {} results for the given search".format(len(candidates)))
#     383 elif not candidates:
#     384     raise UnknownObject
#
# MultipleResults: Found 23 results for the given search

# %% [markdown]
# Making sure the activities have the same "code" across time-specific databases. This is required for now, but we'll fix this soon.

# %%
nodes = [n for d in (important_flows_pem, important_flows_smr) for n, *_ in d.values()]

for node in nodes:
    if node["database"] == db_bio.name:
        continue
    for db in dbs.values():
        node_in_other_db = db.get(
            name=node["name"],
            product=node["reference product"],
            location=node["location"],
        )
        if node["code"] != node_in_other_db["code"]:
            node_in_other_db["code"] = node["code"]
            node_in_other_db.save()

# %%
def flow_dict_to_exchanges(flow_dict, process_type, activity_key):
    exchanges = []
    td = temporal_distributions[process_type]

    for _, flow in flow_dict.items():
        exchange = {
            "amount": flow.amount,
            "type": flow.type,
            "input": activity_key if flow.type == "production" else flow.dataset.key,
            "unit": flow.dataset["unit"],
            "temporal_distribution": td[flow.phase](),
            "operation": flow.phase == "operation",
        }
        exchanges.append(exchange)

    return exchanges

# === Define foreground activities ===
pem_key = ("foreground", "hydrogen_production_pem")
smr_key = ("foreground", "hydrogen_production_smr")

pem_activity = {
    pem_key: {
        "name": "Hydrogen via PEM electrolysis",
        "unit": "kilogram",
        "location": "RER",
        "reference product": "hydrogen",
        "exchanges": flow_dict_to_exchanges(important_flows_pem, "PEM_Electrolysis", pem_key),
        "operation_time_limits": (2,2+10),
    }
}

smr_activity = {
    smr_key: {
        "name": "Hydrogen via Steam Methane Reforming",
        "unit": "kilogram",
        "location": "RER",
        "reference product": "hydrogen",
        "exchanges": flow_dict_to_exchanges(important_flows_smr, "SMR", smr_key),
        "operation_time_limits": (3,3+15),
    }
}

# === Write to foreground database ===
foreground.write({**pem_activity, **smr_activity})
foreground.register()
# Out:
# 22:58:53+0800 [warning  ] Not able to determine geocollections for all datasets. This database is not ready for regionalization.
# 100%|██████████| 2/2 [00:00<00:00, 1067.80it/s]
# 22:58:53+0800 [info     ] Vacuuming database

# %% [markdown]
# ## Running `optimex`

# %%
from datetime import datetime
method = ('EF v3.1 no LT',
  'climate change no LT',
  'global warming potential (GWP100) no LT')

# Define temporally distributed demand from 2025 to 2045
years = range(2025, 2050)
td_demand = bwt.TemporalDistribution(
    date=np.array([datetime(year, 1, 1).isoformat() for year in years], dtype='datetime64[s]'),
    amount=np.asarray([10000] * len(years), dtype=float)  # 100 kg per year
)

# %%
from optimex import lca_processor

lca_config = lca_processor.LCAConfig(
    demand={"hydrogen": td_demand},
    temporal={
        "start_date": datetime(2020, 1, 1),
        "temporal_resolution": "year",
        "time_horizon": 100,
    },
    characterization_methods=[
        {
            "category_name": "climate_change",
            "brightway_method": method,
            "metric": "GWP", # CRF
        },
        {
            "category_name": "resource_depletion",
            "brightway_method": (
                "EF v3.1 no LT",
                "material resources: metals/minerals no LT",
                "abiotic depletion potential (ADP): elements (ultimate reserves) no LT",
            ),
        },
    ],
)

# %% [markdown]
# Preparing LCA tensors:

# %%
lca_data_processor = lca_processor.LCADataProcessor(lca_config)
# Out:
# 2025-07-03 23:41:34.264 | INFO     | optimex.lca_processor:_parse_demand:332 - Identified demand in system time range of %s for functional flows %s
# 2025-07-03 23:41:34.279 | INFO     | optimex.lca_processor:_construct_foreground_tensors:457 - Constructed foreground tensors.
# 2025-07-03 23:41:34.280 | INFO     | optimex.lca_processor:log_tensor_dimensions:452 - Technosphere shape: (2 processes, 10 flows, 19 years) with 98 total entries.
# 2025-07-03 23:41:34.280 | INFO     | optimex.lca_processor:log_tensor_dimensions:452 - Biosphere shape: (2 processes, 4 flows, 17 years) with 59 total entries.
# 2025-07-03 23:41:34.280 | INFO     | optimex.lca_processor:log_tensor_dimensions:452 - Production shape: (2 processes, 1 flows, 17 years) with 27 total entries.
# 2025-07-03 23:41:34.281 | INFO     | optimex.lca_processor:_calculate_inventory_of_db:495 - Calculating inventory for database: ei310_IMAGE_SSP2_RCP19_2020_electricity
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.13e+13)
#   warnings.warn(msg, UmfpackWarning)
# 2025-07-03 23:41:34.832 | INFO     | optimex.lca_processor:_calculate_inventory_of_db:511 - Factorized LCI for database: ei310_IMAGE_SSP2_RCP19_2020_electricity
#   0%|          | 0/10 [00:00<?, ?it/s]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.13e+13)
#   warnings.warn(msg, UmfpackWarning)
#  10%|█         | 1/10 [00:01<00:16,  1.88s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.13e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.13e+13)
#   warnings.warn(msg, UmfpackWarning)
#  20%|██        | 2/10 [00:03<00:14,  1.78s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.13e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.13e+13)
#   warnings.warn(msg, UmfpackWarning)
#  30%|███       | 3/10 [00:05<00:12,  1.78s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.13e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.13e+13)
#   warnings.warn(msg, UmfpackWarning)
#  40%|████      | 4/10 [00:07<00:10,  1.74s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.13e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.13e+13)
#   warnings.warn(msg, UmfpackWarning)
#  50%|█████     | 5/10 [00:08<00:08,  1.79s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.13e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.13e+13)
#   warnings.warn(msg, UmfpackWarning)
#  60%|██████    | 6/10 [00:10<00:07,  1.82s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.13e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.13e+13)
#   warnings.warn(msg, UmfpackWarning)
#  70%|███████   | 7/10 [00:12<00:05,  1.79s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.13e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.13e+13)
#   warnings.warn(msg, UmfpackWarning)
#  80%|████████  | 8/10 [00:14<00:03,  1.78s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.13e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.13e+13)
#   warnings.warn(msg, UmfpackWarning)
#  90%|█████████ | 9/10 [00:16<00:01,  1.77s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.13e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 3.13e+13)
#   warnings.warn(msg, UmfpackWarning)
# 100%|██████████| 10/10 [00:17<00:00,  1.79s/it]
# 2025-07-03 23:41:52.703 | INFO     | optimex.lca_processor:_calculate_inventory_of_db:551 - Finished calculating inventory for database: ei310_IMAGE_SSP2_RCP19_2020_electricity
# 2025-07-03 23:41:52.709 | INFO     | optimex.lca_processor:_calculate_inventory_of_db:495 - Calculating inventory for database: ei310_IMAGE_SSP2_RCP19_2030_electricity
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.30e+13)
#   warnings.warn(msg, UmfpackWarning)
# 2025-07-03 23:41:53.215 | INFO     | optimex.lca_processor:_calculate_inventory_of_db:511 - Factorized LCI for database: ei310_IMAGE_SSP2_RCP19_2030_electricity
#   0%|          | 0/10 [00:00<?, ?it/s]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.30e+13)
#   warnings.warn(msg, UmfpackWarning)
#  10%|█         | 1/10 [00:01<00:16,  1.81s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.30e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.30e+13)
#   warnings.warn(msg, UmfpackWarning)
#  20%|██        | 2/10 [00:03<00:13,  1.75s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.30e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.30e+13)
#   warnings.warn(msg, UmfpackWarning)
#  30%|███       | 3/10 [00:05<00:12,  1.74s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.30e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.30e+13)
#   warnings.warn(msg, UmfpackWarning)
#  40%|████      | 4/10 [00:06<00:10,  1.71s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.30e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.30e+13)
#   warnings.warn(msg, UmfpackWarning)
#  50%|█████     | 5/10 [00:08<00:08,  1.70s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.30e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.30e+13)
#   warnings.warn(msg, UmfpackWarning)
#  60%|██████    | 6/10 [00:10<00:06,  1.69s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.30e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.30e+13)
#   warnings.warn(msg, UmfpackWarning)
#  70%|███████   | 7/10 [00:11<00:05,  1.69s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.30e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.30e+13)
#   warnings.warn(msg, UmfpackWarning)
#  80%|████████  | 8/10 [00:13<00:03,  1.68s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.30e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.30e+13)
#   warnings.warn(msg, UmfpackWarning)
#  90%|█████████ | 9/10 [00:15<00:01,  1.68s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.30e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.30e+13)
#   warnings.warn(msg, UmfpackWarning)
# 100%|██████████| 10/10 [00:16<00:00,  1.70s/it]
# 2025-07-03 23:42:10.205 | INFO     | optimex.lca_processor:_calculate_inventory_of_db:551 - Finished calculating inventory for database: ei310_IMAGE_SSP2_RCP19_2030_electricity
# 2025-07-03 23:42:10.210 | INFO     | optimex.lca_processor:_calculate_inventory_of_db:495 - Calculating inventory for database: ei310_IMAGE_SSP2_RCP19_2040_electricity
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.48e+13)
#   warnings.warn(msg, UmfpackWarning)
# 2025-07-03 23:42:10.686 | INFO     | optimex.lca_processor:_calculate_inventory_of_db:511 - Factorized LCI for database: ei310_IMAGE_SSP2_RCP19_2040_electricity
#   0%|          | 0/10 [00:00<?, ?it/s]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.48e+13)
#   warnings.warn(msg, UmfpackWarning)
#  10%|█         | 1/10 [00:01<00:15,  1.77s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.48e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.48e+13)
#   warnings.warn(msg, UmfpackWarning)
#  20%|██        | 2/10 [00:03<00:13,  1.69s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.48e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.48e+13)
#   warnings.warn(msg, UmfpackWarning)
#  30%|███       | 3/10 [00:05<00:11,  1.68s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.48e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.48e+13)
#   warnings.warn(msg, UmfpackWarning)
#  40%|████      | 4/10 [00:06<00:09,  1.65s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.48e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.48e+13)
#   warnings.warn(msg, UmfpackWarning)
#  50%|█████     | 5/10 [00:13<00:18,  3.61s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.48e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.48e+13)
#   warnings.warn(msg, UmfpackWarning)
#  60%|██████    | 6/10 [00:15<00:11,  2.97s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.48e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.48e+13)
#   warnings.warn(msg, UmfpackWarning)
#  70%|███████   | 7/10 [00:17<00:07,  2.53s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.48e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.48e+13)
#   warnings.warn(msg, UmfpackWarning)
#  80%|████████  | 8/10 [00:18<00:04,  2.25s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.48e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.48e+13)
#   warnings.warn(msg, UmfpackWarning)
#  90%|█████████ | 9/10 [00:20<00:02,  2.07s/it]/Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.48e+13)
#   warnings.warn(msg, UmfpackWarning)
# /Users/timodiepers/anaconda3/envs/optimex/lib/python3.11/site-packages/scikits/umfpack/umfpack.py:736: UmfpackWarning: (almost) singular matrix! (estimated cond. number: 1.48e+13)
#   warnings.warn(msg, UmfpackWarning)
# 100%|██████████| 10/10 [00:22<00:00,  2.22s/it]
# 2025-07-03 23:42:32.884 | INFO     | optimex.lca_processor:_calculate_inventory_of_db:551 - Finished calculating inventory for database: ei310_IMAGE_SSP2_RCP19_2040_electricity
# 2025-07-03 23:42:32.892 | INFO     | optimex.lca_processor:_prepare_background_inventory:658 - Computed background inventory using method: sequential
# 2025-07-03 23:42:32.986 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.
# 2025-07-03 23:42:33.314 | INFO     | optimex.lca_processor:_construct_characterization_tensor:793 - Dynamic GWP characterization for climate_change completed.
# 2025-07-03 23:42:33.326 | INFO     | optimex.lca_processor:_construct_characterization_tensor:769 - Static characterization for method resource_depletion completed.
# 2025-07-03 23:42:33.326 | INFO     | optimex.lca_processor:_construct_mapping_matrix:712 - Constructed mapping matrix for background databases based on linear interpolation.

# %%
from optimex import converter
manager = converter.ModelInputManager()
optimization_model_inputs = manager.parse_from_lca_processor(lca_data_processor)

# %% [markdown]
# Creating the optimization model:

# %%
from optimex import optimizer

model = optimizer.create_model(
    optimization_model_inputs,
    name = "demo_simple_example",
    objective_category = "climate_change", 
    flexible_operation = True, 
)
# Out:
# 2025-07-03 23:42:33.377 | INFO     | optimex.optimizer:create_model:67 - Creating sets
# 2025-07-03 23:42:33.378 | INFO     | optimex.optimizer:create_model:109 - Creating parameters
# 2025-07-03 23:42:33.417 | INFO     | optimex.optimizer:create_model:272 - Creating variables

# %%
m, obj, results = optimizer.solve_model(model, solver_name="glpk", tee=False) # choose solver here, e.g. "gurobi", "cplex", "glpk", etc.
# Out:
# 2025-07-03 23:42:41.394 | INFO     | optimex.optimizer:solve_model:603 - Solver [glpk] termination: optimal
# 2025-07-03 23:42:47.024 | INFO     | optimex.optimizer:solve_model:628 - Objective (scaled): 16.3979
# 2025-07-03 23:42:47.024 | INFO     | optimex.optimizer:solve_model:629 - Objective (real):   1.15992e+06

# %% [markdown]
# ## Results

# %%
from optimex import postprocessing
pp = postprocessing.PostProcessor(m)

# %%
pp.plot_installation()
# Out:
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'Installed Capacity'}, xlabel='Time', ylabel='Installation'>)

# %%
pp.plot_production_and_demand()
# Out:
# (<Figure size 1000x600 with 1 Axes>,
#  <Axes: title={'center': 'Production and Demand'}, xlabel='Time', ylabel='Quantity'>)

# %%
pp.plot_impacts()
# Out:
# (<Figure size 1000x600 with 2 Axes>,
#  array([<Axes: title={'center': 'climate_change'}, xlabel='Time', ylabel='Value'>,
#         <Axes: title={'center': 'resource_depletion'}, xlabel='Time', ylabel='Value'>],
#        dtype=object))

# %% [markdown]
# ### Plotting the resulting radiative forcing

# %%
import pyomo.environ as pyo 
fg_scale = getattr(pp.m, "scales", {}).get("foreground", 1.0)
inventory = {
    (p, e, t): pyo.value(pp.m.scaled_inventory[p, e, t]) * fg_scale
    for p in pp.m.PROCESS
    for e in pp.m.ELEMENTARY_FLOW
    for t in pp.m.SYSTEM_TIME
}

import pandas as pd

dynamic_inventory_df = pd.DataFrame.from_records(
    [(p, e, t, v) for (p, e, t), v in inventory.items()],
    columns=["activity", "flow", "date", "amount"]
).astype({
    "activity": "str",
    "flow": "str",
    # "date": "datetime64[s]",
    "amount": "float64"
})

dynamic_inventory_df['date'] = pd.to_datetime(dynamic_inventory_df['date'].astype(int), format='%Y')

# %%
dynamic_inventory_df
# Out:
#                       activity                                  flow  \
# 0      hydrogen_production_pem  9ec076d9-6d9f-4a0b-9851-730626ed4319
# 1      hydrogen_production_pem  9ec076d9-6d9f-4a0b-9851-730626ed4319
# 2      hydrogen_production_pem  9ec076d9-6d9f-4a0b-9851-730626ed4319
# 3      hydrogen_production_pem  9ec076d9-6d9f-4a0b-9851-730626ed4319
# 4      hydrogen_production_pem  9ec076d9-6d9f-4a0b-9851-730626ed4319
# ...                        ...                                   ...
# 41515  hydrogen_production_smr  cbf58f64-9286-406f-8dcb-ef1d81eec980
# 41516  hydrogen_production_smr  cbf58f64-9286-406f-8dcb-ef1d81eec980
# 41517  hydrogen_production_smr  cbf58f64-9286-406f-8dcb-ef1d81eec980
# 41518  hydrogen_production_smr  cbf58f64-9286-406f-8dcb-ef1d81eec980
# 41519  hydrogen_production_smr  cbf58f64-9286-406f-8dcb-ef1d81eec980
#
#             date  amount
# 0     2020-01-01     0.0
# 1     2021-01-01     0.0
# 2     2022-01-01     0.0
# 3     2023-01-01     0.0
# 4     2024-01-01     0.0
# ...          ...     ...
# 41515 2045-01-01     0.0
# 41516 2046-01-01     0.0
# 41517 2047-01-01     0.0
# 41518 2048-01-01     0.0
# 41519 2049-01-01     0.0
#
# [41520 rows x 4 columns]

# %%
dynamic_inventory_df["flow"] = dynamic_inventory_df["flow"].apply(
    lambda x: db_bio.get(code=x).id
)

# %%
from dynamic_characterization import characterize

df_characterized = characterize(
        dynamic_inventory_df,
        metric="radiative_forcing", # could also be GWP
        base_lcia_method=method,
        time_horizon=100,
        fixed_time_horizon=True,
)
# Out:
# 2025-07-04 00:04:17.526 | INFO     | dynamic_characterization.dynamic_characterization:characterize:82 - No custom dynamic characterization functions provided. Using default dynamic             characterization functions. The flows that are characterized are based on the selection                of the initially chosen impact category.

# %%
df_characterized['date'] = pd.to_datetime(df_characterized['date'])
df_grouped = (
    df_characterized
    .assign(date_rounded=(df_characterized['date'] + pd.offsets.MonthBegin(6)).dt.to_period('Y').dt.to_timestamp())
    .groupby('date_rounded')['amount'].sum()
    .reset_index()
)

df_grouped.plot(x='date_rounded', y='amount')
# Out:
# <Axes: xlabel='date_rounded'>
